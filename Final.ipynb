# %% [markdown]
# <a href="https://colab.research.google.com/github/mhkarimid/Data/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-03-10 15:08:37 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed Preferences ───── v1.3.0
#    Installed Parsers ───────── v2.5.8
#    Installed JSON ──────────── v0.21.3
#    Installed MacroTools ────── v0.5.10
#    Installed Conda ─────────── v1.8.0
#    Installed PyCall ────────── v1.95.1
#    Installed SnoopPrecompile ─ v1.0.3
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.95.1
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.8.0
#   [682c06a0] + JSON v0.21.3
#   [1914dd2f] + MacroTools v0.5.10
#   [69de0a69] + Parsers v2.5.8
#   [21216c6a] + Preferences v1.3.0
#   [438e738f] + PyCall v1.95.1
#   [66db9d55] + SnoopPrecompile v1.0.3
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/62f417f6ad727987c755549e9cd88c46578da562/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/62f417f6ad727987c755549e9cd88c46578da562/build.log`
# Success

# %%
# %pip install -Uq pysr pytorch_lightning
from julia import Julia

julia = Julia(compiled_modules=False, threads='auto')
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 KB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.6/518.6 KB 45.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.1 MB/s eta 0:00:00
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 20.04.5 LTS
#   uname: Linux 5.10.147+ #1 SMP Sat Dec 10 16:00:40 UTC 2022 x86_64 x86_64
#   CPU: AMD EPYC 7B12:
#               speed         user         nice          sys         idle          irq
#        #1  2249 MHz        504 s          0 s        176 s        770 s          0 s
#        #2  2249 MHz        521 s          0 s        158 s        693 s          0 s
#   Memory: 12.681198120117188 GB (11616.1796875 MB free)
#   Uptime: 154.69 sec
#   Load Avg:  1.28  0.64  0.25
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, znver2)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/local/nvidia/lib:/usr/local/nvidia/lib64
#   JULIA_PROJECT = @pysr-0.11.17
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.9.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#      Cloning git-repo `https://github.com/JuliaParallel/ClusterManagers.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed Transducers ────────────────────── v0.4.75
#    Installed GPUArraysCore ──────────────────── v0.1.4
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed DynamicPolynomials ─────────────── v0.4.6
#    Installed MutableArithmetics ─────────────── v1.2.3
#    Installed AutoHashEquals ─────────────────── v0.2.0
#    Installed Adapt ──────────────────────────── v3.6.1
#    Installed DiffRules ──────────────────────── v1.13.0
#    Installed MultivariatePolynomials ────────── v0.4.7
#    Installed LayoutPointers ─────────────────── v0.1.14
#    Installed ArgCheck ───────────────────────── v2.3.0
#    Installed IRTools ────────────────────────── v0.4.8
#    Installed JSON3 ──────────────────────────── v1.12.0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed DynamicExpressions ─────────────── v0.4.2
#    Installed Referenceables ─────────────────── v0.1.2
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed TableTraits ────────────────────── v1.0.1
#    Installed OffsetArrays ───────────────────── v1.12.9
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed TermInterface ──────────────────── v0.2.3
#    Installed Tables ─────────────────────────── v1.10.0
#    Installed SpecialFunctions ───────────────── v2.2.0
#    Installed DataAPI ────────────────────────── v1.14.0
#    Installed Optim ──────────────────────────── v1.7.4
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed CPUSummary ─────────────────────── v0.2.2
#    Installed Zygote ─────────────────────────── v0.6.56
#    Installed TimerOutputs ───────────────────── v0.5.22
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed RecipesBase ────────────────────── v1.3.3
#    Installed LabelledArrays ─────────────────── v1.14.0
#    Installed AbstractFFTs ───────────────────── v1.3.1
#    Installed LoopVectorization ──────────────── v0.12.152
#    Installed JLLWrappers ────────────────────── v1.4.1
#    Installed StaticArrays ───────────────────── v1.5.16
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed StaticArraysCore ───────────────── v1.4.0
#    Installed IteratorInterfaceExtensions ────── v1.0.0
#    Installed Baselet ────────────────────────── v0.1.1
#    Installed MicroCollections ───────────────── v0.1.3
#    Installed ConstructionBase ───────────────── v1.5.1
#    Installed DefineSingletons ───────────────── v0.1.2
#    Installed Bijections ─────────────────────── v0.1.4
#    Installed ArrayInterfaceCore ─────────────── v0.1.29
#    Installed AbstractTrees ──────────────────── v0.4.4
#    Installed DataValueInterfaces ────────────── v1.0.0
#    Installed HostCPUFeatures ────────────────── v0.1.14
#    Installed LLVMExtra_jll ──────────────────── v0.0.16+2
#    Installed OrderedCollections ─────────────── v1.4.1
#    Installed StructArrays ───────────────────── v0.6.14
#    Installed SymbolicIndexingInterface ──────── v0.2.2
#    Installed ChainRulesCore ─────────────────── v1.15.7
#    Installed InitialValues ──────────────────── v0.3.1
#    Installed RecursiveArrayTools ────────────── v2.38.0
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed ThreadingUtilities ─────────────── v0.5.1
#    Installed CEnum ──────────────────────────── v0.4.2
#    Installed Combinatorics ──────────────────── v1.0.2
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ForwardDiff ────────────────────── v0.10.35
#    Installed ArrayInterface ─────────────────── v7.2.1
#    Installed FillArrays ─────────────────────── v0.13.7
#    Installed GPUArrays ──────────────────────── v8.6.3
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed ThreadsX ───────────────────────── v0.1.11
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed PreallocationTools ─────────────── v0.4.12
#    Installed SplittablesBase ────────────────── v0.1.15
#    Installed DataStructures ─────────────────── v0.18.13
#    Installed ChainRules ─────────────────────── v1.48.0
#    Installed LogExpFunctions ────────────────── v0.3.23
#    Installed Metatheory ─────────────────────── v1.3.5
#    Installed Requires ───────────────────────── v1.3.0
#    Installed ProgressBars ───────────────────── v1.4.1
#    Installed ZygoteRules ────────────────────── v0.2.2
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed VectorizationBase ──────────────── v0.21.61
#    Installed ExprTools ──────────────────────── v0.1.9
#    Installed BangBang ───────────────────────── v0.3.37
#    Installed Static ─────────────────────────── v0.8.4
#    Installed CompositionsBase ───────────────── v0.1.1
#    Installed StatsAPI ───────────────────────── v1.5.0
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed Compat ─────────────────────────── v4.6.1
#    Installed InverseFunctions ───────────────── v0.1.8
#    Installed SortingAlgorithms ──────────────── v1.1.0
#    Installed StaticArrayInterface ───────────── v1.3.0
#    Installed Missings ───────────────────────── v1.1.0
#    Installed StatsBase ──────────────────────── v0.33.21
#    Installed SLEEFPirates ───────────────────── v0.6.38
#    Installed LossFunctions ──────────────────── v0.8.0
#    Installed ChangesOfVariables ─────────────── v0.1.6
#    Installed LLVM ───────────────────────────── v4.16.0
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed FiniteDiff ─────────────────────── v2.18.0
#    Installed StructTypes ────────────────────── v1.10.0
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed SymbolicUtils ──────────────────── v0.19.11
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.2 `https://github.com/JuliaParallel/ClusterManagers.jl#14e7302`
#   [8254be44] + SymbolicRegression v0.15.3 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.15.3`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.3.1
#   [1520ce14] + AbstractTrees v0.4.4
#   [79e6a3ab] + Adapt v3.6.1
#   [dce04be8] + ArgCheck v2.3.0
#   [4fba245c] + ArrayInterface v7.2.1
#   [30b0a656] + ArrayInterfaceCore v0.1.29
#   [15f4f7f2] + AutoHashEquals v0.2.0
#   [198e06fe] + BangBang v0.3.37
#   [9718e550] + Baselet v0.1.1
#   [e2ed5e7c] + Bijections v0.1.4
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [fa961155] + CEnum v0.4.2
#   [2a0fbf3d] + CPUSummary v0.2.2
#   [082447d4] + ChainRules v1.48.0
#   [d360d2e6] + ChainRulesCore v1.15.7
#   [9e997f8a] + ChangesOfVariables v0.1.6
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.2 `https://github.com/JuliaParallel/ClusterManagers.jl#14e7302`
#   [861a8166] + Combinatorics v1.0.2
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.6.1
#   [a33af91c] + CompositionsBase v0.1.1
#   [187b0558] + ConstructionBase v1.5.1
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.14.0
#   [864edb3b] + DataStructures v0.18.13
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.13.0
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.4.2
#   [7c1d4256] + DynamicPolynomials v0.4.6
#   [e2ba6199] + ExprTools v0.1.9
#   [1a297f60] + FillArrays v0.13.7
#   [6a86dc24] + FiniteDiff v2.18.0
#   [f6369f11] + ForwardDiff v0.10.35
#   [0c68f7d7] + GPUArrays v8.6.3
#   [46192b85] + GPUArraysCore v0.1.4
#   [3e5b6fbb] + HostCPUFeatures v0.1.14
#   [7869d1d1] + IRTools v0.4.8
#   [615f187c] + IfElse v0.1.1
#   [22cec73e] + InitialValues v0.3.1
#   [3587e190] + InverseFunctions v0.1.8
#   [92d709cd] + IrrationalConstants v0.2.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.4.1
#   [0f8b85d8] + JSON3 v1.12.0
#   [929cbde3] + LLVM v4.16.0
#   [2ee39098] + LabelledArrays v1.14.0
#   [10f19ff3] + LayoutPointers v0.1.14
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.23
#   [bdcacae8] + LoopVectorization v0.12.152
#   [30fc2ffe] + LossFunctions v0.8.0
#   [d125e4d3] + ManualMemory v0.1.8
# ⌅ [e9d8d322] + Metatheory v1.3.5
#   [128add7d] + MicroCollections v0.1.3
#   [e1d29d7a] + Missings v1.1.0
#   [102ac46a] + MultivariatePolynomials v0.4.7
#   [d8a4904e] + MutableArithmetics v1.2.3
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.9
#   [429524aa] + Optim v1.7.4
#   [bac558e1] + OrderedCollections v1.4.1
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [d236fae5] + PreallocationTools v0.4.12
#   [49802e3a] + ProgressBars v1.4.1
#   [c1ae055f] + RealDot v0.1.0
#   [3cdcf5f2] + RecipesBase v1.3.3
#   [731186ca] + RecursiveArrayTools v2.38.0
#   [189a3867] + Reexport v1.2.2
#   [42d2dcc6] + Referenceables v0.1.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.38
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.1.0
#   [276daf66] + SpecialFunctions v2.2.0
#   [171d559e] + SplittablesBase v0.1.15
#   [aedffcd0] + Static v0.8.4
#   [0d7ed370] + StaticArrayInterface v1.3.0
#   [90137ffa] + StaticArrays v1.5.16
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [82ae8749] + StatsAPI v1.5.0
#   [2913bbd2] + StatsBase v0.33.21
#   [09ab397b] + StructArrays v0.6.14
#   [856f2bd8] + StructTypes v1.10.0
#   [2efcf032] + SymbolicIndexingInterface v0.2.2
#   [8254be44] + SymbolicRegression v0.15.3 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.15.3`
# ⌅ [d1185830] + SymbolicUtils v0.19.11
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.10.0
# ⌅ [8ea1fca8] + TermInterface v0.2.3
#   [8290d209] + ThreadingUtilities v0.5.1
#   [ac1d9e8a] + ThreadsX v0.1.11
#   [a759f4b9] + TimerOutputs v0.5.22
#   [28d57a85] + Transducers v0.4.75
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.61
#   [e88e6eb3] + Zygote v0.6.56
#   [700de1a5] + ZygoteRules v0.2.2
#   [dad2f222] + LLVMExtra_jll v0.0.16+2
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [4af54fe1] + LazyArtifacts
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.9/dist-packages/pysr/julia_helpers.py:105: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
df=pd.read_csv('https://raw.githubusercontent.com/mhkarimid/Data/main/newdata.csv', 
               names=['Time (min)', 'Gold grade (g/ton)', 'Pyrite content (wt.%)',
               'Ore content (wt.%)', 'pH', 'ORP (mV)', 'D-Gal (wt.%)',
               'D-Suc (wt.%)', 'D-FrU (wt.%)', 'Ferric (g/lit)', 'Pyrite dissolution (%)'])
df.head()
# Out:
#    Time (min)  Gold grade (g/ton)  Pyrite content (wt.%)  Ore content (wt.%)  \
# 0   -0.500000                 0.5                    0.5           -0.444444
# 1   -0.456522                 0.5                    0.5           -0.444444
# 2   -0.413043                 0.5                    0.5           -0.444444
# 3   -0.369565                 0.5                    0.5           -0.444444
# 4   -0.326087                 0.5                    0.5           -0.444444
#
#          pH  ORP (mV)  D-Gal (wt.%)  D-Suc (wt.%)  D-FrU (wt.%)  \
# 0 -0.191734 -0.460602     -0.155844     -0.155844     -0.155844
# 1 -0.201303 -0.443605     -0.155844     -0.155844     -0.155844
# 2 -0.244366 -0.432274     -0.155844     -0.155844     -0.155844
# 3 -0.273074 -0.304795     -0.155844     -0.155844     -0.155844
# 4 -0.225227 -0.214143     -0.155844     -0.155844     -0.155844
#
#    Ferric (g/lit)  Pyrite dissolution (%)
# 0       -0.177262               -0.339150
# 1       -0.161934               -0.323117
# 2       -0.165186               -0.327591
# 3       -0.131744               -0.278188
# 4       -0.118739               -0.251342

# %%
XX=df.drop(['Gold grade (g/ton)','Ferric (g/lit)','Pyrite dissolution (%)'], axis=1)
yy=df['Pyrite dissolution (%)']

Rtr=[]
RMSEtr=[]

Rte=[]
RMSEte=[]


for i in range(1,10):
  X_tr, X_te, y_tr, y_te = train_test_split(XX, yy, test_size=0.05*i, random_state=42)
  X = X_tr.values.tolist()
  y = y_tr.transpose().values.tolist()

  Xte = X_te.values.tolist()
  yte = y_te.transpose().values.tolist()
  default_pysr_params = dict(
      populations=10,
      model_selection="accuracy",
      loss="L1DistLoss()",
      maxsize=30,
      precision=16,
      )
  model = PySRRegressor( 
      niterations=100,
      binary_operators=["+", "-", "*", "/"],
      unary_operators=["inv(x) = 1/x", "P2(x)=x", "P4(x)=x", "exp", "neg","sinh", "cosh"],
      extra_sympy_mappings={"inv": lambda x: 1/x, "P2": lambda x: x**0.3, "P4": lambda x: x**0.7},
      **default_pysr_params
      )
  model.fit(X, y)
  y2=model.predict(Xte)
  
  dk=pd.DataFrame(data=[yte,y2])
  d=dk.transpose().corr()[1]
  SS=d.squeeze()[0]
  Rte.append(SS)
  rmse=(mean_squared_error(yte, y2))
  RMSEte.append(rmse)
  
  y3=model.predict(X)
  
  dk=pd.DataFrame(data=[y,y3])
  d=dk.transpose().corr()[1]
  SS=d.squeeze()[0]
  Rtr.append(SS)
  rmse=(mean_squared_error(y, y3))
  RMSEtr.append(rmse)
# Out:
# /usr/local/lib/python3.9/dist-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pysr/julia_helpers.py:217: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# Started!
#
# Cycles per second: 1.410e+03
# Head worker occupation: 0.1%
# Progress: 4 / 1000 total iterations (0.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 11          6.909e-02  1.170e-02  (inv((-1.51 / P4(0.04916 - x4)) + -0.669) * 1.296)
# 12          6.775e-02  1.972e-02  (P2(inv(P2(-1.51 / (0.03696 - x4)) + -0.669)) * 1.296)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.500e+03
# Head worker occupation: 0.2%
# Progress: 14 / 1000 total iterations (1.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 6           7.361e-02  1.008e-02  ((x4 / 1.057) / cosh(x4))
# 8           6.287e-02  7.891e-02  (((x4 * x4) - sinh(0.05112)) + x4)
# 14          6.262e-02  6.523e-04  (inv(P2(P2(-1.51) / (0.0732 - x4)) + P4(-1.51)) * P2(1.472))
# 18          6.180e-02  3.318e-03  P4(P2(inv((P2(P2(-1.51) / (0.0732 - P2(sinh(x4)))) + -0.1396) + -1.51)) * 1.472)
# 22          6.165e-02  6.111e-04  P4(inv(P4(P2(P2((P2(-1.51) / (0.0732 - sinh(x4))) + -0.255)) - (x3 * x1)) + -1.51) * 1.472)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.830e+03
# Head worker occupation: 0.2%
# Progress: 24 / 1000 total iterations (2.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.562e-02  1.712e-03  (x4 / cosh(sinh(x4)))
# 6           6.940e-02  8.612e-02  (x4 / cosh(x4 + -0.2808))
# 8           6.287e-02  4.949e-02  (((x4 * x4) - sinh(0.05112)) + x4)
# 9           6.049e-02  3.883e-02  (((P4(x4) * x4) - 0.05112) + sinh(x4))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.190e+03
# Head worker occupation: 0.2%
# Progress: 36 / 1000 total iterations (3.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.562e-02  1.712e-03  (x4 / cosh(sinh(x4)))
# 6           6.940e-02  8.612e-02  (x4 / cosh(x4 + -0.2808))
# 7           6.738e-02  2.923e-02  sinh(x4 / cosh(x4 + x4))
# 8           6.287e-02  6.924e-02  (((x4 * x4) - sinh(0.05112)) + x4)
# 9           6.049e-02  3.883e-02  (((P4(x4) * x4) - 0.05112) + sinh(x4))
# 24          5.920e-02  1.415e-03  (((P2(x1 + x4) / sinh((((P2(x1 * 2.26) + 2.889) - x4) - sinh(sinh(x4))) - x4)) + x4) * 0.7646)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.650e+03
# Head worker occupation: 0.2%
# Progress: 52 / 1000 total iterations (5.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.824e-02  5.469e-02  (x4 / cosh(x4 + x4))
# 7           6.287e-02  8.188e-02  (((x4 * x4) - 0.05112) + x4)
# 8           6.049e-02  3.883e-02  (((x4 * x4) - 0.05112) + sinh(x4))
# 9           6.006e-02  6.859e-03  sinh(((x4 * x4) - 0.05112) + sinh(x4))
# 11          6.003e-02  2.442e-04  (P4(((x4 * x4) - 0.05112) * 0.913) + sinh(x4))
# 13          5.997e-02  4.885e-04  (P4(sinh((P4(x4) * x4) - 0.05112) * 0.913) + sinh(x4))
# 16          5.984e-02  6.517e-04  sinh((-0.0488 * sinh(x4 * x4)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 20          5.963e-02  8.560e-04  sinh(((sinh(sinh(sinh(x4))) * 0.05112) * (x0 * -0.864)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 21          5.960e-02  4.884e-04  sinh(((cosh(x4 * x1) * -0.0488) * (x4 * x0)) + (((x4 * x4) - P2(0.05112)) + sinh(x4)))
# 23          5.884e-02  6.388e-03  P2(sinh(((cosh(x4 * (x1 / sinh(sinh(x4)))) * -0.01624) * x0) + (((x4 * x4) - 0.06287) + sinh(x4))))
# 24          5.881e-02  4.884e-04  (((P4(sinh(sinh(sinh(x4)) * (x0 / x4))) * 0.05112) * (x0 * -0.864)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 25          5.814e-02  1.129e-02  ((((x1 + x4) / P4(sinh(((((x1 * 2.26) + 2.889) - x4) - (sinh(sinh(x4)) + x4)) - x4))) + x4) * 0.7646)
# 26          5.795e-02  2.934e-03  ((((x1 + x4) / sinh((((P4(x1 * 2.26) + 2.889) - x4) - sinh(sinh(sinh(x4)) + x4)) - x4)) + x4) * 0.7646)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.740e+03
# Head worker occupation: 0.3%
# Progress: 65 / 1000 total iterations (6.500%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.824e-02  5.469e-02  (x4 / cosh(x4 + x4))
# 7           6.287e-02  8.188e-02  (((x4 * x4) - 0.05112) + x4)
# 8           6.049e-02  3.883e-02  (((x4 * x4) - 0.05112) + sinh(x4))
# 9           6.006e-02  6.859e-03  sinh(((x4 * x4) - 0.05112) + sinh(x4))
# 10          5.978e-02  4.404e-03  P4((((x4 * x4) - 0.0994) + x4) + 0.02846)
# 11          5.920e-02  9.814e-03  sinh((P2(x4 * P2(x4)) - 0.05927) + sinh(x4))
# 12          5.896e-02  3.914e-03  ((P4(P2(x4 * P2(x4))) - 0.06213) + sinh(P4(x4)))
# 23          5.881e-02  2.222e-04  (((P4(sinh(sinh(x4) * (x0 / x4))) * 0.05112) * (x0 * -0.864)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 25          5.814e-02  5.647e-03  ((((x1 + x4) / P4(sinh(((((x1 * 2.26) + 2.889) - x4) - (sinh(sinh(x4)) + x4)) - x4))) + x4) * 0.7646)
# 26          5.795e-02  2.934e-03  ((((x1 + x4) / sinh((((P4(x1 * 2.26) + 2.889) - x4) - sinh(sinh(sinh(x4)) + x4)) - x4)) + x4) * 0.7646)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.670e+03
# Head worker occupation: 0.2%
# Progress: 75 / 1000 total iterations (7.500%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.824e-02  5.469e-02  (x4 / cosh(x4 + x4))
# 7           6.287e-02  8.188e-02  (((x4 * x4) - 0.05112) + x4)
# 8           6.049e-02  3.883e-02  (((x4 * x4) - 0.05112) + sinh(x4))
# 9           5.942e-02  1.773e-02  sinh((P2(x4 * x4) - 0.06976) + x4)
# 11          5.920e-02  1.712e-03  sinh((P2(x4 * P2(x4)) - 0.05927) + sinh(x4))
# 12          5.896e-02  3.914e-03  ((P4(P2(x4 * P2(x4))) - 0.06213) + sinh(P4(x4)))
# 16          5.856e-02  1.715e-03  ((x4 * (sinh(neg(x0)) * 0.1113)) + P2(((x4 * x4) - 0.05618) + x4))
# 23          5.829e-02  6.993e-04  P4((P2(x4 - x1) * (x1 * P2(0.1171 + 0.1292))) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.814e-02  1.222e-03  ((((x1 + x4) / P4(sinh(((((x1 * 2.26) + 2.889) - x4) - (sinh(sinh(x4)) + x4)) - x4))) + x4) * 0.7646)
# 26          5.795e-02  2.934e-03  ((((x1 + x4) / sinh((((P4(x1 * 2.26) + 2.889) - x4) - sinh(sinh(sinh(x4)) + x4)) - x4)) + x4) * 0.7646)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.520e+03
# Head worker occupation: 0.3%
# Progress: 83 / 1000 total iterations (8.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.824e-02  5.469e-02  (x4 / cosh(x4 + x4))
# 7           6.287e-02  8.188e-02  (((x4 * x4) - 0.05112) + x4)
# 8           5.899e-02  6.350e-02  (((x4 * x4) - 0.06366) + sinh(x4))
# 12          5.896e-02  1.221e-04  ((P4(P2(x4 * P2(x4))) - 0.06213) + sinh(P4(x4)))
# 15          5.859e-02  2.123e-03  ((x4 * (neg(x0) * 0.1113)) + P2(((x4 * x4) - 0.05618) + x4))
# 16          5.856e-02  4.884e-04  ((x4 * (sinh(neg(x0)) * 0.1113)) + P2(((x4 * x4) - 0.05618) + x4))
# 23          5.829e-02  6.993e-04  P4((P2(x4 - x1) * (x1 * P2(0.1171 + 0.1292))) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.814e-02  1.222e-03  ((((x1 + x4) / P4(sinh(((((x1 * 2.26) + 2.889) - x4) - (sinh(sinh(x4)) + x4)) - x4))) + x4) * 0.7646)
# 26          5.795e-02  2.934e-03  ((((x1 + x4) / sinh((((P4(x1 * 2.26) + 2.889) - x4) - sinh(sinh(sinh(x4)) + x4)) - x4)) + x4) * 0.7646)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.560e+03
# Head worker occupation: 0.3%
# Progress: 95 / 1000 total iterations (9.500%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.824e-02  5.469e-02  (x4 / cosh(x4 + x4))
# 7           5.978e-02  1.324e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.899e-02  1.327e-02  (((x4 * x4) - 0.06366) + sinh(x4))
# 12          5.896e-02  1.221e-04  ((P4(P2(x4 * P2(x4))) - 0.06213) + sinh(P4(x4)))
# 14          5.795e-02  8.619e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 24          5.762e-02  5.877e-04  (((sinh(sinh(x2)) / ((sinh(P2(x4)) + -1.324) + x4)) * 0.05862) + ((P4(P2(x4) * x4) - 0.05862) + sinh(x4)))
# 28          5.719e-02  1.838e-03  sinh((((x2 * 0.352) / ((sinh(P2(x4)) + (-1.324 + x2)) + P2(x4))) * 0.05862) + ((P4(P2(x4) * x4) - 0.05862) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.750e+03
# Head worker occupation: 0.3%
# Progress: 111 / 1000 total iterations (11.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.824e-02  5.469e-02  (x4 / cosh(x4 + x4))
# 7           5.978e-02  1.324e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.899e-02  1.327e-02  (((x4 * x4) - 0.06366) + sinh(x4))
# 9           5.893e-02  9.770e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 14          5.795e-02  3.348e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 23          5.780e-02  1.832e-04  P4((sinh(x4 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 24          5.740e-02  6.859e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 27          5.710e-02  1.795e-03  P4((sinh(sinh(0.05112) - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - P2(0.05112)) + sinh(P2(x4))))
# 28          5.551e-02  2.823e-02  P4((sinh(x4 - x1) * ((x1 * P2((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - P2(0.05112)) + sinh(P2(x4))))
# 29          5.542e-02  1.466e-03  P4((sinh(sinh(x4 - x1)) * ((x1 * P2((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - P2(0.05112)) + sinh(P2(x4))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 3.990e+03
# Head worker occupation: 0.3%
# Progress: 123 / 1000 total iterations (12.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.899e-02  1.327e-02  (((x4 * x4) - 0.06366) + sinh(x4))
# 9           5.893e-02  9.770e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 14          5.795e-02  3.348e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 23          5.780e-02  1.832e-04  P4((sinh(x4 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 24          5.740e-02  6.859e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 26          5.560e-02  1.587e-02  P4(((x4 - x1) * ((x1 * P2((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 27          5.551e-02  1.466e-03  P4((sinh(x4 - x1) * ((x1 * P2((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 28          5.548e-02  4.884e-04  P4((sinh(x4 - x1) * (sinh(x1 * P2((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 29          5.496e-02  9.321e-03  P4((sinh(x4 - x1) * ((x1 * P2((0.1171 + 0.1292) + (x4 * 0.8677))) * 0.8677)) + (((x4 * x4) - sinh(0.05112)) + sinh(P2(x4))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.060e+03
# Head worker occupation: 0.3%
# Progress: 136 / 1000 total iterations (13.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.899e-02  1.327e-02  (((x4 * x4) - 0.06366) + sinh(x4))
# 9           5.893e-02  9.770e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 14          5.795e-02  3.348e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 23          5.780e-02  1.832e-04  P4((sinh(x4 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 24          5.740e-02  6.859e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.698e-02  7.351e-03  P4((sinh(x4 - x1) * ((x1 * P2(0.1292 + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 26          5.554e-02  2.572e-02  P4(P2((P2(x4 - x1) * ((x1 * (P2(x3) + 0.2651)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
# 27          5.548e-02  9.770e-04  P4((sinh(x4 - x1) * (sinh(x1 * ((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 29          5.496e-02  4.660e-03  P4((sinh(x4 - x1) * ((x1 * P2((0.1171 + 0.1292) + (x4 * 0.8677))) * 0.8677)) + (((x4 * x4) - sinh(0.05112)) + sinh(P2(x4))))
# 30          5.444e-02  9.321e-03  P4(P2((P4(x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.210e+03
# Head worker occupation: 0.3%
# Progress: 151 / 1000 total iterations (15.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 23          5.780e-02  1.832e-04  P4((sinh(x4 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 24          5.740e-02  6.859e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.695e-02  7.843e-03  ((((P2(exp(exp(x4))) * 0.01239) * x2) * (neg(0.06064) - P2(exp(x4)))) + (((P2(x4) * x4) - 0.06064) + sinh(x4)))
# 26          5.554e-02  2.472e-02  P4(P2((P2(x4 - x1) * ((x1 * (P2(x3) + 0.2651)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
# 27          5.548e-02  9.770e-04  P4((sinh(x4 - x1) * (sinh(x1 * ((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 29          5.496e-02  4.660e-03  P4((sinh(x4 - x1) * ((x1 * P2((0.1171 + 0.1292) + (x4 * 0.8677))) * 0.8677)) + (((x4 * x4) - sinh(0.05112)) + sinh(P2(x4))))
# 30          5.444e-02  9.321e-03  P4(P2((P4(x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.150e+03
# Head worker occupation: 0.3%
# Progress: 162 / 1000 total iterations (16.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 22          5.762e-02  6.993e-04  P4((sinh(x0 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P2(x4) * x4) - 0.05112) + sinh(x4)))
# 24          5.740e-02  1.957e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.695e-02  7.843e-03  ((((P2(exp(exp(x4))) * 0.01239) * x2) * (neg(0.06064) - P2(exp(x4)))) + (((P2(x4) * x4) - 0.06064) + sinh(x4)))
# 26          5.554e-02  2.472e-02  P4(P2((P2(x4 - x1) * ((x1 * (P2(x3) + 0.2651)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
# 27          5.548e-02  9.770e-04  P4((sinh(x4 - x1) * (sinh(x1 * ((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 29          5.444e-02  9.364e-03  P4(P2(((x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.030e+03
# Head worker occupation: 0.3%
# Progress: 174 / 1000 total iterations (17.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 22          5.762e-02  6.993e-04  P4((sinh(x0 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P2(x4) * x4) - 0.05112) + sinh(x4)))
# 24          5.740e-02  1.957e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.695e-02  7.843e-03  ((((P2(exp(exp(x4))) * 0.01239) * x2) * (neg(0.06064) - P2(exp(x4)))) + (((P2(x4) * x4) - 0.06064) + sinh(x4)))
# 26          5.554e-02  2.472e-02  P4(P2((P2(x4 - x1) * ((x1 * (P2(x3) + 0.2651)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
# 27          5.548e-02  9.770e-04  P4((sinh(x4 - x1) * (sinh(x1 * ((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 29          5.444e-02  9.364e-03  P4(P2(((x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.160e+03
# Head worker occupation: 0.3%
# Progress: 190 / 1000 total iterations (19.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 22          5.762e-02  6.993e-04  P4((sinh(x0 - x1) * ((x1 * P2(0.1292)) * 0.563)) + (((P2(x4) * x4) - 0.05112) + sinh(x4)))
# 24          5.740e-02  1.957e-03  P4(((x4 - x1) * ((x1 * P2(0.1171 + 0.1292)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.695e-02  7.843e-03  ((((P2(exp(exp(x4))) * 0.01239) * x2) * (neg(0.06064) - P2(exp(x4)))) + (((P2(x4) * x4) - 0.06064) + sinh(x4)))
# 26          5.554e-02  2.472e-02  P4(P2((P2(x4 - x1) * ((x1 * (P2(x3) + 0.2651)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
# 27          5.548e-02  9.770e-04  P4((sinh(x4 - x1) * (sinh(x1 * ((0.1171 + 0.1292) + x3)) * 0.563)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4))))
# 29          5.444e-02  9.364e-03  P4(P2(((x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.270e+03
# Head worker occupation: 0.3%
# Progress: 202 / 1000 total iterations (20.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 21          5.740e-02  1.389e-03  P4(((x4 - x1) * (x1 * P2(P2(0.1292)))) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4))))
# 23          5.624e-02  1.011e-02  P4(((x4 - x1) * (x1 * P2(0.1171 + (0.1292 * x4)))) + (((x4 * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.609e-02  1.467e-03  P4(sinh(((x4 - x1) * (x1 * P2(0.1171 + (0.1292 * x4)))) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4)))))
# 26          5.527e-02  1.476e-02  P4(((x4 - (x1 + -0.2167)) * (x1 * P2(0.1171 + P2(0.1292)))) + (((P4(x4) * x4) - 0.05112) + P2(P2(sinh(x4)))))
# 29          5.444e-02  5.084e-03  P4(P2(((x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.360e+03
# Head worker occupation: 0.3%
# Progress: 212 / 1000 total iterations (21.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 19          5.753e-02  1.795e-03  sinh(((x4 - x1) * (x1 * P2(P2(0.1171)))) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 20          5.734e-02  3.424e-03  P2((x2 * ((-0.383 - x0) * 0.1113)) + ((P2(x4 * x4) - sinh(0.05618 / 0.801)) + x4))
# 22          5.688e-02  3.922e-03  P2(((neg(0.1602) + x2) * ((-0.383 - x4) * 0.1113)) + (((x4 * P4(x4)) - (0.05618 / 0.801)) + x4))
# 23          5.624e-02  1.129e-02  P4(((x4 - x1) * (x1 * P2(0.1171 + (0.1292 * x4)))) + (((x4 * x4) - 0.05112) + P2(sinh(x4))))
# 25          5.609e-02  1.467e-03  P4(sinh(((x4 - x1) * (x1 * P2(0.1171 + (0.1292 * x4)))) + (((P4(x4) * x4) - 0.05112) + P2(sinh(x4)))))
# 26          5.527e-02  1.476e-02  P4(((x4 - (x1 + -0.2167)) * (x1 * P2(0.1171 + P2(0.1292)))) + (((P4(x4) * x4) - 0.05112) + P2(P2(sinh(x4)))))
# 29          5.444e-02  5.084e-03  P4(P2(((x4 - x1) * ((x1 * (P2((x4 + 0.1292) + x3) + 0.2651)) * 0.4177)) + (((P4(x4) * x4) - 0.05112) + sinh(P2(x4)))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.340e+03
# Head worker occupation: 0.3%
# Progress: 224 / 1000 total iterations (22.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 19          5.743e-02  2.286e-03  (((x4 - P2(x1)) * (x1 * P4(0.1171))) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 20          5.423e-02  5.727e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 22          5.417e-02  4.885e-04  ((sinh((sinh(x4) - -0.5312) - x1) * (x1 * P4(0.1171))) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 27          5.209e-02  7.766e-03  (((sinh(P2(0.129) - P4(x1)) + x4) * (sinh(x1) * ((0.649 + x4) * 0.3047))) + (((x4 * x4) - P4(0.05112)) + sinh(x4)))
# 28          5.206e-02  4.884e-04  (((sinh(P2(0.129) - P4(x1)) + x4) * sinh(sinh(x1) * ((0.649 + x4) * 0.3047))) + (((x4 * x4) - P4(0.05112)) + sinh(x4)))
# 30          5.188e-02  1.712e-03  ((sinh(P4(P2(0.129) - sinh(x1)) + x4) * (x1 * ((0.649 + P2(x4)) * sinh(P4(0.3047))))) + (((x4 * x4) - P4(0.05112)) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.210e+03
# Head worker occupation: 0.3%
# Progress: 238 / 1000 total iterations (23.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 12          5.887e-02  3.257e-04  (sinh(((x4 * x4) - 0.06366) + sinh(P4(x4))) / 1.027)
# 14          5.795e-02  7.874e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.743e-02  3.430e-03  (((x4 - P2(x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 20          5.423e-02  2.864e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 22          5.417e-02  4.885e-04  ((sinh((sinh(x4) - -0.5312) - x1) * (x1 * P4(0.1171))) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 24          5.215e-02  1.891e-02  ((sinh(sinh((P4(x4) - -0.5312) - x1)) * (x1 * P2(P4(0.1171)))) + (((P2(x4) * x4) - 0.05112) + sinh(x4)))
# 26          4.913e-02  2.993e-02  (P2(P4(sinh(sinh(sinh(P2((P2(x4) - -0.4763) - x1)))) * (x1 * 0.0939))) + (((x4 * P2(x4)) - 0.04352) + sinh(x4)))
# 27          4.834e-02  1.624e-02  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4958) - x1)))) + -0.4958) * (x1 * 0.1171)) + (((x4 * P2(x4)) - 0.05112) + sinh(x4)))
# 28          4.803e-02  6.368e-03  (P2(P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152))) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.230e+03
# Head worker occupation: 0.3%
# Progress: 249 / 1000 total iterations (24.900%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 14          5.795e-02  5.249e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 20          5.261e-02  1.992e-02  ((sinh(sinh((x4 - -0.5464) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + x4))
# 21          5.215e-02  8.828e-03  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 26          4.913e-02  1.197e-02  (P2(P4(sinh(sinh(sinh(P2((P2(x4) - -0.4763) - x1)))) * (x1 * 0.0939))) + (((x4 * P2(x4)) - 0.04352) + sinh(x4)))
# 27          4.803e-02  2.272e-02  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.190e+03
# Head worker occupation: 0.3%
# Progress: 260 / 1000 total iterations (26.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 14          5.795e-02  5.249e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 20          5.261e-02  1.992e-02  ((sinh(sinh((x4 - -0.5464) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + x4))
# 21          5.215e-02  8.828e-03  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 23          4.913e-02  2.993e-02  (P4(sinh(sinh(sinh(P2((x4 - -0.4763) - x1)))) * (x1 * 0.0939)) + (((x4 * x4) - 0.04352) + sinh(x4)))
# 26          4.889e-02  1.632e-03  (P4(sinh(sinh(sinh(P2(P2((P4(x4) - sinh(-0.4763)) - x1))))) * (x1 * 0.0939)) + (((x4 * x4) - 0.04352) + sinh(x4)))
# 27          4.803e-02  1.773e-02  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.200e+03
# Head worker occupation: 0.3%
# Progress: 275 / 1000 total iterations (27.500%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 14          5.795e-02  5.249e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 20          5.261e-02  1.992e-02  ((sinh(sinh((x4 - -0.5464) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + x4))
# 21          5.215e-02  8.828e-03  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 22          5.090e-02  2.422e-02  ((sinh(sinh(sinh((P2(x4) - -0.4763) - x1))) * sinh(x1 * 0.0939)) + (((x4 * x4) - 0.04352) + x4))
# 23          4.889e-02  4.035e-02  ((sinh(sinh(sinh((x4 - sinh(-0.4763)) - x1))) * (x1 * 0.0939)) + ((P4(x4 * x4) - 0.04352) + sinh(x4)))
# 24          4.840e-02  9.814e-03  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(sinh(x1))))) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
# 27          4.803e-02  2.450e-03  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.250e+03
# Head worker occupation: 0.3%
# Progress: 287 / 1000 total iterations (28.700%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 14          5.795e-02  5.249e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 19          5.463e-02  2.444e-03  ((sinh((P2(x4) - -0.4763) - x1) * (x1 * 0.1599)) + (((x4 * x4) - 0.04352) + x4))
# 20          5.261e-02  3.782e-02  ((sinh(sinh((x4 - -0.5464) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + x4))
# 21          5.215e-02  8.828e-03  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 22          5.090e-02  2.422e-02  ((sinh(sinh(sinh((P2(x4) - -0.4763) - x1))) * sinh(x1 * 0.0939)) + (((x4 * x4) - 0.04352) + x4))
# 23          4.889e-02  4.035e-02  ((sinh(sinh(sinh((x4 - sinh(-0.4763)) - x1))) * (x1 * 0.0939)) + ((P4(x4 * x4) - 0.04352) + sinh(x4)))
# 24          4.840e-02  9.814e-03  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(sinh(x1))))) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
# 27          4.803e-02  2.450e-03  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.320e+03
# Head worker occupation: 0.3%
# Progress: 301 / 1000 total iterations (30.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 14          5.795e-02  5.249e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 19          5.463e-02  2.444e-03  ((sinh((P2(x4) - -0.4763) - x1) * (x1 * 0.1599)) + (((x4 * x4) - 0.04352) + x4))
# 20          5.261e-02  3.782e-02  ((sinh(sinh((x4 - -0.5464) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + x4))
# 21          5.215e-02  8.828e-03  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((P4(x4) * x4) - 0.05112) + sinh(x4)))
# 22          5.090e-02  2.422e-02  ((sinh(sinh(sinh((P2(x4) - -0.4763) - x1))) * sinh(x1 * 0.0939)) + (((x4 * x4) - 0.04352) + x4))
# 23          4.889e-02  4.035e-02  ((sinh(sinh(sinh((x4 - sinh(-0.4763)) - x1))) * (x1 * 0.0939)) + ((P4(x4 * x4) - 0.04352) + sinh(x4)))
# 24          4.840e-02  9.814e-03  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(sinh(x1))))) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
# 27          4.803e-02  2.450e-03  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.090e+03
# Head worker occupation: 0.3%
# Progress: 311 / 1000 total iterations (31.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 14          5.795e-02  5.249e-03  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 19          5.463e-02  2.444e-03  ((sinh((P2(x4) - -0.4763) - x1) * (x1 * 0.1599)) + (((x4 * x4) - 0.04352) + x4))
# 20          5.215e-02  4.647e-02  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 22          5.090e-02  1.211e-02  ((sinh(sinh(sinh((P2(x4) - -0.4763) - x1))) * sinh(x1 * 0.0939)) + (((x4 * x4) - 0.04352) + x4))
# 23          4.889e-02  4.035e-02  ((sinh(sinh(sinh((x4 - sinh(-0.4763)) - x1))) * (x1 * 0.0939)) + ((P4(x4 * x4) - 0.04352) + sinh(x4)))
# 24          4.840e-02  9.814e-03  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(sinh(x1))))) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
# 27          4.803e-02  2.450e-03  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.020e+03
# Head worker occupation: 0.3%
# Progress: 321 / 1000 total iterations (32.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 13          5.865e-02  1.712e-03  sinh(((x4 * x4) - (cosh(x1) * (0.05762 / 0.857))) + x4)
# 14          5.795e-02  1.228e-02  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 19          5.463e-02  2.444e-03  ((sinh((P2(x4) - -0.4763) - x1) * (x1 * 0.1599)) + (((x4 * x4) - 0.04352) + x4))
# 20          5.215e-02  4.647e-02  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 22          5.063e-02  1.487e-02  ((sinh(sinh(sinh((x4 - sinh(-0.4763)) - x1))) * (x1 * 0.0939)) + ((P4(x4 * x4) - 0.04352) + x4))
# 23          4.889e-02  3.478e-02  ((sinh(sinh(sinh((x4 - sinh(-0.4763)) - x1))) * (x1 * 0.0939)) + ((P4(x4 * x4) - 0.04352) + sinh(x4)))
# 24          4.840e-02  9.814e-03  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(sinh(x1))))) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
# 27          4.803e-02  2.450e-03  (P4((sinh(sinh(sinh(P2((P2(x4) - -0.4946) - x1)))) + -0.4956) * (x1 * 0.1152)) + (((x4 * P2(x4)) - 0.04617) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.000e+03
# Head worker occupation: 0.3%
# Progress: 330 / 1000 total iterations (33.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 13          5.865e-02  1.712e-03  sinh(((x4 * x4) - (cosh(x1) * (0.05762 / 0.857))) + x4)
# 14          5.795e-02  1.228e-02  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 16          5.783e-02  9.770e-04  ((sinh(sinh(x0)) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 18          5.475e-02  2.735e-02  ((sinh((x4 - -0.5312) - x1) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 19          5.261e-02  3.985e-02  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + x4))
# 20          5.215e-02  8.828e-03  ((sinh(sinh((x4 - -0.5312) - x1)) * (x1 * 0.1171)) + (((x4 * x4) - 0.05112) + sinh(x4)))
# 22          4.865e-02  3.488e-02  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(x1)))) * (x1 * 0.0939)) + (((x4 * x4) - 0.04352) + sinh(x4)))
# 24          4.840e-02  2.447e-03  ((sinh(sinh(sinh((x4 - -0.4763) - sinh(sinh(x1))))) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
# 27          4.739e-02  7.073e-03  (((sinh(sinh(sinh((x4 - P2(-0.4763)) - sinh(sinh(x1))))) - 0.2502) * (x1 * 0.0939)) + (((x4 * x4) - P4(0.04352)) + sinh(x4)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.060e+03
# Head worker occupation: 0.3%
# Progress: 342 / 1000 total iterations (34.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.258e-02  9.436e-01  x4
# 3           7.587e-02  4.253e-02  (x4 * 0.8384)
# 5           7.208e-02  2.554e-02  (x4 / sinh(cosh(x4)))
# 6           6.720e-02  7.028e-02  (x4 / cosh(x4 / -0.551))
# 7           5.978e-02  1.169e-01  (((x4 * x4) - 0.0707) + x4)
# 8           5.896e-02  1.377e-02  (((x4 * x4) - 0.0627) + sinh(x4))
# 9           5.893e-02  4.884e-04  ((sinh(x4 * x4) - 0.06366) + sinh(x4))
# 11          5.887e-02  4.885e-04  (sinh(((x4 * x4) - 0.06366) + sinh(x4)) / 1.027)
# 13          5.865e-02  1.712e-03  sinh(((x4 * x4) - (cosh(x1) * (0.05762 / 0.857))) + x4)
# 14          5.795e-02  1.228e-02  ((x0 * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# 15          5.789e-02  9.770e-04  ((sinh(x0) * (neg(x0) * 0.1113)) + (((x4 * x4) - 0.05618) + x4))
# ...
# 22          4.767e-02  3.914e-03  (((x4 * (x4 + 1.701)) - ((sinh((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(sinh(x1)))) / 1.701)
# 23          4.739e-02  5.877e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.010e+03
# Head worker occupation: 0.4%
# Progress: 925 / 1000 total iterations (92.500%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 11          5.902e-02  1.346e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.853e-02  2.286e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.716)
# 17          4.904e-02  1.769e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.767e-02  3.914e-03  (((x4 * (x4 + 1.701)) - ((sinh((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(sinh(x1)))) / 1.701)
# 23          4.739e-02  5.877e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.070e+03
# Head worker occupation: 0.4%
# Progress: 938 / 1000 total iterations (93.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 11          5.902e-02  1.346e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.853e-02  2.286e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.716)
# 17          4.904e-02  1.769e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.767e-02  3.914e-03  (((x4 * (x4 + 1.701)) - ((sinh((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(sinh(x1)))) / 1.701)
# 23          4.739e-02  5.877e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.150e+03
# Head worker occupation: 0.4%
# Progress: 950 / 1000 total iterations (95.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 11          5.902e-02  1.346e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.804e-02  5.084e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.733)
# 17          4.904e-02  1.687e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.767e-02  3.914e-03  (((x4 * (x4 + 1.701)) - ((sinh((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(sinh(x1)))) / 1.701)
# 23          4.739e-02  5.877e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.210e+03
# Head worker occupation: 0.4%
# Progress: 964 / 1000 total iterations (96.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 11          5.902e-02  1.346e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.804e-02  5.084e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.733)
# 17          4.904e-02  1.687e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.767e-02  3.914e-03  (((x4 * (x4 + 1.701)) - ((sinh((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(sinh(x1)))) / 1.701)
# 23          4.739e-02  5.877e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.210e+03
# Head worker occupation: 0.4%
# Progress: 973 / 1000 total iterations (97.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 11          5.902e-02  1.346e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.804e-02  5.084e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.733)
# 17          4.904e-02  1.687e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.767e-02  3.914e-03  (((x4 * (x4 + 1.701)) - ((sinh((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(sinh(x1)))) / 1.701)
# 23          4.739e-02  5.877e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.150e+03
# Head worker occupation: 0.4%
# Progress: 982 / 1000 total iterations (98.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 11          5.902e-02  1.346e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.804e-02  5.084e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.733)
# 17          4.904e-02  1.687e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.755e-02  6.368e-03  (((x4 * (x4 + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 23          4.739e-02  3.424e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 4.140e+03
# Head worker occupation: 0.4%
# Progress: 992 / 1000 total iterations (99.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.234e-02  9.413e-01  x4
# 3           7.568e-02  4.200e-02  (x4 * 0.8345)
# 5           7.208e-02  2.426e-02  (x4 / sinh(cosh(x4)))
# 6           6.714e-02  7.081e-02  (x4 / cosh(x4 / 0.5366))
# 7           5.933e-02  1.235e-01  ((x4 * (x4 + 1.0205)) + -0.0662)
# 10          5.911e-02  1.141e-03  ((sinh(x4) * ((x4 + 1.0205) - 0.01706)) + -0.0662)
# 11          5.902e-02  1.466e-03  (((x4 * ((x4 * 2.512) + 2.729)) + -0.1655) / 2.729)
# 13          5.893e-02  7.330e-04  (((sinh(sinh(x4)) * ((x4 * 2.512) + 2.562)) + -0.1655) / 2.645)
# 16          5.804e-02  5.084e-03  (((x4 * (x4 + 1.716)) - (((x1 - 0.5933) * x1) * neg(x1))) / 1.733)
# 17          4.904e-02  1.687e-01  (((x4 * (x4 + 1.734)) - (((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 18          4.895e-02  1.955e-03  (((x4 * (x4 + 1.734)) - sinh(((x1 + -0.5903) * x1) * (x4 - x1))) / 1.8125)
# 20          4.874e-02  2.202e-03  (((x4 * (x4 + 1.716)) - ((((x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 21          4.785e-02  1.823e-02  (((x4 * (x4 + 1.716)) - (((sinh(x1 + -0.537) * (x1 - x4)) + -0.0656) * neg(x1))) / 1.716)
# 22          4.755e-02  6.368e-03  (((x4 * (x4 + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 23          4.739e-02  3.424e-03  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((x1 + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 24          4.736e-02  4.884e-04  (((x4 * (sinh(x4) + 1.716)) - ((sinh(sinh((sinh(x1) + -0.537) * (x1 - x4))) + -0.0656) * neg(x1))) / 1.701)
# 28          4.730e-02  3.665e-04  (((x4 * (x4 + 1.716)) - (sinh((sinh(sinh((sinh(x1) + -0.537) * (x1 - P2(x4)))) / 1.095) + -0.0656) * neg(P4(x1)))) / 1.716)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
# <lambdifygenerated-9>:2: RuntimeWarning: invalid value encountered in power
#   return (0.582750582750583*x1**0.7*sinh(0.91324200913242*sinh(sinh((x1 - x4**0.3)*(sinh(x1) - 0.537))) - 0.0656) + 0.582750582750583*x4*(x4 + 1.716))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b20ef9613412> in <module>
#      37   SS=d.squeeze()[0]
#      38   Rte.append(SS)
# ---> 39   rmse=(mean_squared_error(yte, y2))
#      40   RMSEte.append(rmse)
#      41
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103
#     104     if y_true.ndim == 1:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input contains NaN.

# %%
i
# Out:
# 3

# %%
y2
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.63350959,        nan,
#               nan,        nan,        nan,        nan,        nan,
#        0.60340461,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan, 0.59221324,
#               nan, 0.72008743,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.65934818,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan, 0.65031747,
#               nan,        nan,        nan, 0.70733686,        nan,
#               nan, 0.57111239,        nan, 0.75134714,        nan,
#        0.73789498,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.54577204,        nan,
#               nan,        nan,        nan,        nan, 0.68103795,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan, 0.73383915,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.57834621, 0.66307638,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan, 0.71199108,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan, 0.70756535,        nan,
#               nan,        nan,        nan,        nan, 0.81237802,
#               nan,        nan, 0.73207846,        nan,        nan,
#        0.55395259,        nan])

# %%
Xte
# Out:
# [[0.152173913,
#   -0.5,
#   0.555555556,
#   0.186256361,
#   0.134298605,
#   -0.155844156,
#   -0.155844156,
#   0.844155844],
#  [-0.02173913,
#   0.5,
#   -0.111111111,
#   -0.019485266,
#   0.292938831,
#   -0.155844156,
#   -0.064935065,
#   -0.155844156],
#  [-0.282608696,
#   -0.1,
#   -0.111111111,
#   0.119270715,
#   -0.262301962,
#   -0.064935065,
#   -0.155844156,
#   -0.155844156],
#  [-0.456521739,
#   -0.1,
#   -0.444444444,
#   0.109701337,
#   -0.437939356,
#   -0.155844156,
#   0.844155844,
#   -0.155844156],
#  [-0.065217391,
#   0.1,
#   -0.444444444,
#   -0.057762778,
#   0.080474242,
#   -0.155844156,
#   -0.155844156,
#   -0.155844156],
#  [0.065217391,
#   0.1,
#   -0.111111111,
#   0.195825739,
#   0.24194733,
#   -0.064935065,
#   -0.155844156,
#   -0.155844156],
#  [-0.326086957,
#   0.5,
#   -0.444444444,
#   -0.119963735,
#   -0.13765607,
#   0.844155844,
#   -0.155844156,
#   -0.155844156],
#  [-0.02173913,
#   -0.3,
#   -0.444444444,
#   0.133624782,
#   0.216451579,
#   -0.155844156,
#   -0.155844156,
#   0.844155844],
#  [0