# %% [markdown]
# <a href="https://colab.research.google.com/github/mhkarimid/Data/blob/main/Genetic%20programming-%20data%20portion%20test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-03-10 15:08:37 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed Preferences ───── v1.3.0
#    Installed Parsers ───────── v2.5.8
#    Installed JSON ──────────── v0.21.3
#    Installed MacroTools ────── v0.5.10
#    Installed Conda ─────────── v1.8.0
#    Installed PyCall ────────── v1.95.1
#    Installed SnoopPrecompile ─ v1.0.3
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.95.1
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.8.0
#   [682c06a0] + JSON v0.21.3
#   [1914dd2f] + MacroTools v0.5.10
#   [69de0a69] + Parsers v2.5.8
#   [21216c6a] + Preferences v1.3.0
#   [438e738f] + PyCall v1.95.1
#   [66db9d55] + SnoopPrecompile v1.0.3
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/62f417f6ad727987c755549e9cd88c46578da562/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/62f417f6ad727987c755549e9cd88c46578da562/build.log`
# Success

# %%
# %pip install -Uq pysr pytorch_lightning
from julia import Julia

julia = Julia(compiled_modules=False, threads='auto')
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 KB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.6/518.6 KB 45.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.1 MB/s eta 0:00:00
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 20.04.5 LTS
#   uname: Linux 5.10.147+ #1 SMP Sat Dec 10 16:00:40 UTC 2022 x86_64 x86_64
#   CPU: AMD EPYC 7B12:
#               speed         user         nice          sys         idle          irq
#        #1  2249 MHz        504 s          0 s        176 s        770 s          0 s
#        #2  2249 MHz        521 s          0 s        158 s        693 s          0 s
#   Memory: 12.681198120117188 GB (11616.1796875 MB free)
#   Uptime: 154.69 sec
#   Load Avg:  1.28  0.64  0.25
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, znver2)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/local/nvidia/lib:/usr/local/nvidia/lib64
#   JULIA_PROJECT = @pysr-0.11.17
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.9.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#      Cloning git-repo `https://github.com/JuliaParallel/ClusterManagers.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed Transducers ────────────────────── v0.4.75
#    Installed GPUArraysCore ──────────────────── v0.1.4
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed DynamicPolynomials ─────────────── v0.4.6
#    Installed MutableArithmetics ─────────────── v1.2.3
#    Installed AutoHashEquals ─────────────────── v0.2.0
#    Installed Adapt ──────────────────────────── v3.6.1
#    Installed DiffRules ──────────────────────── v1.13.0
#    Installed MultivariatePolynomials ────────── v0.4.7
#    Installed LayoutPointers ─────────────────── v0.1.14
#    Installed ArgCheck ───────────────────────── v2.3.0
#    Installed IRTools ────────────────────────── v0.4.8
#    Installed JSON3 ──────────────────────────── v1.12.0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed DynamicExpressions ─────────────── v0.4.2
#    Installed Referenceables ─────────────────── v0.1.2
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed TableTraits ────────────────────── v1.0.1
#    Installed OffsetArrays ───────────────────── v1.12.9
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed TermInterface ──────────────────── v0.2.3
#    Installed Tables ─────────────────────────── v1.10.0
#    Installed SpecialFunctions ───────────────── v2.2.0
#    Installed DataAPI ────────────────────────── v1.14.0
#    Installed Optim ──────────────────────────── v1.7.4
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed CPUSummary ─────────────────────── v0.2.2
#    Installed Zygote ─────────────────────────── v0.6.56
#    Installed TimerOutputs ───────────────────── v0.5.22
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed RecipesBase ────────────────────── v1.3.3
#    Installed LabelledArrays ─────────────────── v1.14.0
#    Installed AbstractFFTs ───────────────────── v1.3.1
#    Installed LoopVectorization ──────────────── v0.12.152
#    Installed JLLWrappers ────────────────────── v1.4.1
#    Installed StaticArrays ───────────────────── v1.5.16
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed StaticArraysCore ───────────────── v1.4.0
#    Installed IteratorInterfaceExtensions ────── v1.0.0
#    Installed Baselet ────────────────────────── v0.1.1
#    Installed MicroCollections ───────────────── v0.1.3
#    Installed ConstructionBase ───────────────── v1.5.1
#    Installed DefineSingletons ───────────────── v0.1.2
#    Installed Bijections ─────────────────────── v0.1.4
#    Installed ArrayInterfaceCore ─────────────── v0.1.29
#    Installed AbstractTrees ──────────────────── v0.4.4
#    Installed DataValueInterfaces ────────────── v1.0.0
#    Installed HostCPUFeatures ────────────────── v0.1.14
#    Installed LLVMExtra_jll ──────────────────── v0.0.16+2
#    Installed OrderedCollections ─────────────── v1.4.1
#    Installed StructArrays ───────────────────── v0.6.14
#    Installed SymbolicIndexingInterface ──────── v0.2.2
#    Installed ChainRulesCore ─────────────────── v1.15.7
#    Installed InitialValues ──────────────────── v0.3.1
#    Installed RecursiveArrayTools ────────────── v2.38.0
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed ThreadingUtilities ─────────────── v0.5.1
#    Installed CEnum ──────────────────────────── v0.4.2
#    Installed Combinatorics ──────────────────── v1.0.2
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ForwardDiff ────────────────────── v0.10.35
#    Installed ArrayInterface ─────────────────── v7.2.1
#    Installed FillArrays ─────────────────────── v0.13.7
#    Installed GPUArrays ──────────────────────── v8.6.3
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed ThreadsX ───────────────────────── v0.1.11
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed PreallocationTools ─────────────── v0.4.12
#    Installed SplittablesBase ────────────────── v0.1.15
#    Installed DataStructures ─────────────────── v0.18.13
#    Installed ChainRules ─────────────────────── v1.48.0
#    Installed LogExpFunctions ────────────────── v0.3.23
#    Installed Metatheory ─────────────────────── v1.3.5
#    Installed Requires ───────────────────────── v1.3.0
#    Installed ProgressBars ───────────────────── v1.4.1
#    Installed ZygoteRules ────────────────────── v0.2.2
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed VectorizationBase ──────────────── v0.21.61
#    Installed ExprTools ──────────────────────── v0.1.9
#    Installed BangBang ───────────────────────── v0.3.37
#    Installed Static ─────────────────────────── v0.8.4
#    Installed CompositionsBase ───────────────── v0.1.1
#    Installed StatsAPI ───────────────────────── v1.5.0
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed Compat ─────────────────────────── v4.6.1
#    Installed InverseFunctions ───────────────── v0.1.8
#    Installed SortingAlgorithms ──────────────── v1.1.0
#    Installed StaticArrayInterface ───────────── v1.3.0
#    Installed Missings ───────────────────────── v1.1.0
#    Installed StatsBase ──────────────────────── v0.33.21
#    Installed SLEEFPirates ───────────────────── v0.6.38
#    Installed LossFunctions ──────────────────── v0.8.0
#    Installed ChangesOfVariables ─────────────── v0.1.6
#    Installed LLVM ───────────────────────────── v4.16.0
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed FiniteDiff ─────────────────────── v2.18.0
#    Installed StructTypes ────────────────────── v1.10.0
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed SymbolicUtils ──────────────────── v0.19.11
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.2 `https://github.com/JuliaParallel/ClusterManagers.jl#14e7302`
#   [8254be44] + SymbolicRegression v0.15.3 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.15.3`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.3.1
#   [1520ce14] + AbstractTrees v0.4.4
#   [79e6a3ab] + Adapt v3.6.1
#   [dce04be8] + ArgCheck v2.3.0
#   [4fba245c] + ArrayInterface v7.2.1
#   [30b0a656] + ArrayInterfaceCore v0.1.29
#   [15f4f7f2] + AutoHashEquals v0.2.0
#   [198e06fe] + BangBang v0.3.37
#   [9718e550] + Baselet v0.1.1
#   [e2ed5e7c] + Bijections v0.1.4
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [fa961155] + CEnum v0.4.2
#   [2a0fbf3d] + CPUSummary v0.2.2
#   [082447d4] + ChainRules v1.48.0
#   [d360d2e6] + ChainRulesCore v1.15.7
#   [9e997f8a] + ChangesOfVariables v0.1.6
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.2 `https://github.com/JuliaParallel/ClusterManagers.jl#14e7302`
#   [861a8166] + Combinatorics v1.0.2
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.6.1
#   [a33af91c] + CompositionsBase v0.1.1
#   [187b0558] + ConstructionBase v1.5.1
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.14.0
#   [864edb3b] + DataStructures v0.18.13
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.13.0
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.4.2
#   [7c1d4256] + DynamicPolynomials v0.4.6
#   [e2ba6199] + ExprTools v0.1.9
#   [1a297f60] + FillArrays v0.13.7
#   [6a86dc24] + FiniteDiff v2.18.0
#   [f6369f11] + ForwardDiff v0.10.35
#   [0c68f7d7] + GPUArrays v8.6.3
#   [46192b85] + GPUArraysCore v0.1.4
#   [3e5b6fbb] + HostCPUFeatures v0.1.14
#   [7869d1d1] + IRTools v0.4.8
#   [615f187c] + IfElse v0.1.1
#   [22cec73e] + InitialValues v0.3.1
#   [3587e190] + InverseFunctions v0.1.8
#   [92d709cd] + IrrationalConstants v0.2.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.4.1
#   [0f8b85d8] + JSON3 v1.12.0
#   [929cbde3] + LLVM v4.16.0
#   [2ee39098] + LabelledArrays v1.14.0
#   [10f19ff3] + LayoutPointers v0.1.14
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.23
#   [bdcacae8] + LoopVectorization v0.12.152
#   [30fc2ffe] + LossFunctions v0.8.0
#   [d125e4d3] + ManualMemory v0.1.8
# ⌅ [e9d8d322] + Metatheory v1.3.5
#   [128add7d] + MicroCollections v0.1.3
#   [e1d29d7a] + Missings v1.1.0
#   [102ac46a] + MultivariatePolynomials v0.4.7
#   [d8a4904e] + MutableArithmetics v1.2.3
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.9
#   [429524aa] + Optim v1.7.4
#   [bac558e1] + OrderedCollections v1.4.1
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [d236fae5] + PreallocationTools v0.4.12
#   [49802e3a] + ProgressBars v1.4.1
#   [c1ae055f] + RealDot v0.1.0
#   [3cdcf5f2] + RecipesBase v1.3.3
#   [731186ca] + RecursiveArrayTools v2.38.0
#   [189a3867] + Reexport v1.2.2
#   [42d2dcc6] + Referenceables v0.1.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.38
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.1.0
#   [276daf66] + SpecialFunctions v2.2.0
#   [171d559e] + SplittablesBase v0.1.15
#   [aedffcd0] + Static v0.8.4
#   [0d7ed370] + StaticArrayInterface v1.3.0
#   [90137ffa] + StaticArrays v1.5.16
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [82ae8749] + StatsAPI v1.5.0
#   [2913bbd2] + StatsBase v0.33.21
#   [09ab397b] + StructArrays v0.6.14
#   [856f2bd8] + StructTypes v1.10.0
#   [2efcf032] + SymbolicIndexingInterface v0.2.2
#   [8254be44] + SymbolicRegression v0.15.3 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.15.3`
# ⌅ [d1185830] + SymbolicUtils v0.19.11
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.10.0
# ⌅ [8ea1fca8] + TermInterface v0.2.3
#   [8290d209] + ThreadingUtilities v0.5.1
#   [ac1d9e8a] + ThreadsX v0.1.11
#   [a759f4b9] + TimerOutputs v0.5.22
#   [28d57a85] + Transducers v0.4.75
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.61
#   [e88e6eb3] + Zygote v0.6.56
#   [700de1a5] + ZygoteRules v0.2.2
#   [dad2f222] + LLVMExtra_jll v0.0.16+2
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [4af54fe1] + LazyArtifacts
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.9/dist-packages/pysr/julia_helpers.py:105: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
df=pd.read_csv('https://raw.githubusercontent.com/mhkarimid/Data/main/newdata.csv', 
               names=['Time (min)', 'Gold grade (g/ton)', 'Pyrite content (wt.%)',
               'Ore content (wt.%)', 'pH', 'ORP (mV)', 'D-Gal (wt.%)',
               'D-Suc (wt.%)', 'D-FrU (wt.%)', 'Ferric (g/lit)', 'Pyrite dissolution (%)'])
df.head()
# Out:
#    Time (min)  Gold grade (g/ton)  Pyrite content (wt.%)  Ore content (wt.%)  \
# 0   -0.500000                 0.5                    0.5           -0.444444
# 1   -0.456522                 0.5                    0.5           -0.444444
# 2   -0.413043                 0.5                    0.5           -0.444444
# 3   -0.369565                 0.5                    0.5           -0.444444
# 4   -0.326087                 0.5                    0.5           -0.444444
#
#          pH  ORP (mV)  D-Gal (wt.%)  D-Suc (wt.%)  D-FrU (wt.%)  \
# 0 -0.191734 -0.460602     -0.155844     -0.155844     -0.155844
# 1 -0.201303 -0.443605     -0.155844     -0.155844     -0.155844
# 2 -0.244366 -0.432274     -0.155844     -0.155844     -0.155844
# 3 -0.273074 -0.304795     -0.155844     -0.155844     -0.155844
# 4 -0.225227 -0.214143     -0.155844     -0.155844     -0.155844
#
#    Ferric (g/lit)  Pyrite dissolution (%)
# 0       -0.177262               -0.339150
# 1       -0.161934               -0.323117
# 2       -0.165186               -0.327591
# 3       -0.131744               -0.278188
# 4       -0.118739               -0.251342

# %%
XX=df.drop(['Gold grade (g/ton)','Ferric (g/lit)','Pyrite dissolution (%)'], axis=1)
yy=df['Pyrite dissolution (%)']

Rtr=[]
RMSEtr=[]

Rte=[]
RMSEte=[]


for i in range(1,10):
  X_tr, X_te, y_tr, y_te = train_test_split(XX, yy, test_size=0.05*i, random_state=42)
  X = X_tr.values.tolist()
  y = y_tr.transpose().values.tolist()
  default_pysr_params = dict(
      populations=10,
      model_selection="accuracy",
      loss="L1DistLoss()",
      maxsize=30,
      precision=16,
      )
  model = PySRRegressor( 
      niterations=100,
      binary_operators=["+", "-", "*", "/", "^"],
      unary_operators=["inv(x) = 1/x", "P2(x)=x", "P3(x)=x", "P4(x)=x", "exp", "neg", "erf","sinh", "cosh"],
      extra_sympy_mappings={"inv": lambda x: 1/x, "P2": lambda x: x**0.3, "P3": lambda x: x**0.5, "P4": lambda x: x**0.7},
      **default_pysr_params
      )
  model.fit(X, y)
  y2=model.predict(X_te)
  
  dk=pd.DataFrame(data=[y_te,y2])
  d=dk.transpose().corr()[1]
  SS=d.squeeze()[0]
  Rte.append(SS)
  rmse=np.sqrt(mean_squared_error(y, y2))
  RMSEte.append(rmse)
  
  y3=model.predict(X_tr)
  
  dk=pd.DataFrame(data=[y_tr,y3])
  d=dk.transpose().corr()[1]
  SS=d.squeeze()[0]
  Rtr.append(SS)
  rmse=np.sqrt(mean_squared_error(y, y2))
  RMSEtr.append(rmse)
# Out:
# /usr/local/lib/python3.9/dist-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
