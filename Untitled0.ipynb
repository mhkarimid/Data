# %% [markdown]
# <a href="https://colab.research.google.com/github/mhkarimid/Data/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2023-03-10 04:39:17 URL:https://julialang-s3.julialang.org/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed SnoopPrecompile ─ v1.0.3
#    Installed MacroTools ────── v0.5.10
#    Installed Conda ─────────── v1.8.0
#    Installed Preferences ───── v1.3.0
#    Installed JSON ──────────── v0.21.3
#    Installed Parsers ───────── v2.5.8
#    Installed PyCall ────────── v1.95.1
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.95.1
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.8.0
#   [682c06a0] + JSON v0.21.3
#   [1914dd2f] + MacroTools v0.5.10
#   [69de0a69] + Parsers v2.5.8
#   [21216c6a] + Preferences v1.3.0
#   [438e738f] + PyCall v1.95.1
#   [66db9d55] + SnoopPrecompile v1.0.3
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/62f417f6ad727987c755549e9cd88c46578da562/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e32a90da027ca45d84678b826fffd3110bb3fc90/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/62f417f6ad727987c755549e9cd88c46578da562/build.log`
# Success

# %%
# %pip install -Uq pysr pytorch_lightning
from julia import Julia

julia = Julia(compiled_modules=False, threads='auto')
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 KB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.6/518.6 KB 40.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 20.6 MB/s eta 0:00:00
# Julia Version 1.8.5
# Commit 17cfb8e65ea (2023-01-08 06:45 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 20.04.5 LTS
#   uname: Linux 5.10.147+ #1 SMP Sat Dec 10 16:00:40 UTC 2022 x86_64 x86_64
#   CPU: Intel(R) Xeon(R) CPU @ 2.20GHz:
#               speed         user         nice          sys         idle          irq
#        #1  2199 MHz        795 s          0 s        230 s        649 s          0 s
#        #2  2199 MHz        800 s          0 s        252 s        536 s          0 s
#   Memory: 12.681198120117188 GB (11331.2421875 MB free)
#   Uptime: 178.61 sec
#   Load Avg:  1.61  0.91  0.37
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, broadwell)
#   Threads: 1 on 2 virtual cores
# Environment:
#   LD_LIBRARY_PATH = /usr/local/nvidia/lib:/usr/local/nvidia/lib64
#   JULIA_PROJECT = @pysr-0.11.17
#   JULIA_PKG_PRECOMPILE_AUTO = 0
#   TCLLIBPATH = /usr/share/tcltk/tcllib1.20
#   HOME = /root
#   PYTHONPATH = /env/python
#   LIBRARY_PATH = /usr/local/cuda/lib64/stubs
#   PATH = /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
#   COLAB_DEBUG_ADAPTER_MUX_PATH = /usr/local/bin/dap_multiplexer
#   TERM = xterm-color
# [ Info: Julia version info
# [ Info: Julia executable: /usr/local/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Info: PyCall is already installed and compatible with Python executable.
# │
# │ PyCall:
# │     python: /usr/bin/python3
# │     libpython: /usr/lib/x86_64-linux-gnu/libpython3.9.so.1.0
# │ Python:
# │     python: /usr/bin/python3
# └     libpython:
#      Cloning git-repo `https://github.com/MilesCranmer/SymbolicRegression.jl`
#      Cloning git-repo `https://github.com/JuliaParallel/ClusterManagers.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed GPUArraysCore ──────────────────── v0.1.4
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed DynamicPolynomials ─────────────── v0.4.6
#    Installed IRTools ────────────────────────── v0.4.8
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed MutableArithmetics ─────────────── v1.2.3
#    Installed DynamicExpressions ─────────────── v0.4.2
#    Installed AutoHashEquals ─────────────────── v0.2.0
#    Installed Transducers ────────────────────── v0.4.75
#    Installed Adapt ──────────────────────────── v3.6.1
#    Installed DiffRules ──────────────────────── v1.13.0
#    Installed OffsetArrays ───────────────────── v1.12.9
#    Installed MultivariatePolynomials ────────── v0.4.7
#    Installed LayoutPointers ─────────────────── v0.1.14
#    Installed ArgCheck ───────────────────────── v2.3.0
#    Installed VectorizationBase ──────────────── v0.21.61
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed JSON3 ──────────────────────────── v1.12.0
#    Installed TableTraits ────────────────────── v1.0.1
#    Installed Referenceables ─────────────────── v0.1.2
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed CPUSummary ─────────────────────── v0.2.2
#    Installed Tables ─────────────────────────── v1.10.0
#    Installed TermInterface ──────────────────── v0.2.3
#    Installed SpecialFunctions ───────────────── v2.2.0
#    Installed Optim ──────────────────────────── v1.7.4
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed DataAPI ────────────────────────── v1.14.0
#    Installed TimerOutputs ───────────────────── v0.5.22
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed Baselet ────────────────────────── v0.1.1
#    Installed LabelledArrays ─────────────────── v1.14.0
#    Installed Zygote ─────────────────────────── v0.6.56
#    Installed StaticArrays ───────────────────── v1.5.16
#    Installed LoopVectorization ──────────────── v0.12.152
#    Installed SymbolicUtils ──────────────────── v0.19.11
#    Installed AbstractFFTs ───────────────────── v1.3.1
#    Installed StaticArraysCore ───────────────── v1.4.0
#    Installed NaNMath ────────────────────────── v1.0.2
#    Installed IteratorInterfaceExtensions ────── v1.0.0
#    Installed ConstructionBase ───────────────── v1.5.1
#    Installed JLLWrappers ────────────────────── v1.4.1
#    Installed MicroCollections ───────────────── v0.1.3
#    Installed DefineSingletons ───────────────── v0.1.2
#    Installed ArrayInterfaceCore ─────────────── v0.1.29
#    Installed Bijections ─────────────────────── v0.1.4
#    Installed LLVMExtra_jll ──────────────────── v0.0.16+2
#    Installed HostCPUFeatures ────────────────── v0.1.14
#    Installed StructArrays ───────────────────── v0.6.14
#    Installed DataValueInterfaces ────────────── v1.0.0
#    Installed AbstractTrees ──────────────────── v0.4.4
#    Installed OrderedCollections ─────────────── v1.4.1
#    Installed ThreadingUtilities ─────────────── v0.5.1
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed SymbolicIndexingInterface ──────── v0.2.2
#    Installed InitialValues ──────────────────── v0.3.1
#    Installed RecursiveArrayTools ────────────── v2.38.0
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed ChainRulesCore ─────────────────── v1.15.7
#    Installed Combinatorics ──────────────────── v1.0.2
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ArrayInterface ─────────────────── v7.2.1
#    Installed FillArrays ─────────────────────── v0.13.7
#    Installed CEnum ──────────────────────────── v0.4.2
#    Installed ForwardDiff ────────────────────── v0.10.35
#    Installed GPUArrays ──────────────────────── v8.6.3
#    Installed ThreadsX ───────────────────────── v0.1.11
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed DataStructures ─────────────────── v0.18.13
#    Installed PreallocationTools ─────────────── v0.4.12
#    Installed SplittablesBase ────────────────── v0.1.15
#    Installed ChainRules ─────────────────────── v1.48.0
#    Installed Metatheory ─────────────────────── v1.3.5
#    Installed Requires ───────────────────────── v1.3.0
#    Installed LogExpFunctions ────────────────── v0.3.23
#    Installed ProgressBars ───────────────────── v1.4.1
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed ZygoteRules ────────────────────── v0.2.2
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed BangBang ───────────────────────── v0.3.37
#    Installed ExprTools ──────────────────────── v0.1.9
#    Installed Static ─────────────────────────── v0.8.4
#    Installed StatsAPI ───────────────────────── v1.5.0
#    Installed Compat ─────────────────────────── v4.6.1
#    Installed CompositionsBase ───────────────── v0.1.1
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed SLEEFPirates ───────────────────── v0.6.38
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed InverseFunctions ───────────────── v0.1.8
#    Installed SortingAlgorithms ──────────────── v1.1.0
#    Installed StaticArrayInterface ───────────── v1.3.0
#    Installed StatsBase ──────────────────────── v0.33.21
#    Installed LLVM ───────────────────────────── v4.16.0
#    Installed Missings ───────────────────────── v1.1.0
#    Installed ChangesOfVariables ─────────────── v0.1.6
#    Installed StructTypes ────────────────────── v1.10.0
#    Installed LossFunctions ──────────────────── v0.8.0
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed FiniteDiff ─────────────────────── v2.18.0
#    Installed RecipesBase ────────────────────── v1.3.3
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [34f1f09b] + ClusterManagers v0.4.2 `https://github.com/JuliaParallel/ClusterManagers.jl#14e7302`
#   [8254be44] + SymbolicRegression v0.15.3 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.15.3`
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.3.1
#   [1520ce14] + AbstractTrees v0.4.4
#   [79e6a3ab] + Adapt v3.6.1
#   [dce04be8] + ArgCheck v2.3.0
#   [4fba245c] + ArrayInterface v7.2.1
#   [30b0a656] + ArrayInterfaceCore v0.1.29
#   [15f4f7f2] + AutoHashEquals v0.2.0
#   [198e06fe] + BangBang v0.3.37
#   [9718e550] + Baselet v0.1.1
#   [e2ed5e7c] + Bijections v0.1.4
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [fa961155] + CEnum v0.4.2
#   [2a0fbf3d] + CPUSummary v0.2.2
#   [082447d4] + ChainRules v1.48.0
#   [d360d2e6] + ChainRulesCore v1.15.7
#   [9e997f8a] + ChangesOfVariables v0.1.6
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [34f1f09b] + ClusterManagers v0.4.2 `https://github.com/JuliaParallel/ClusterManagers.jl#14e7302`
#   [861a8166] + Combinatorics v1.0.2
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.6.1
#   [a33af91c] + CompositionsBase v0.1.1
#   [187b0558] + ConstructionBase v1.5.1
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.14.0
#   [864edb3b] + DataStructures v0.18.13
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.13.0
#   [ffbed154] + DocStringExtensions v0.9.3
#   [a40a106e] + DynamicExpressions v0.4.2
#   [7c1d4256] + DynamicPolynomials v0.4.6
#   [e2ba6199] + ExprTools v0.1.9
#   [1a297f60] + FillArrays v0.13.7
#   [6a86dc24] + FiniteDiff v2.18.0
#   [f6369f11] + ForwardDiff v0.10.35
#   [0c68f7d7] + GPUArrays v8.6.3
#   [46192b85] + GPUArraysCore v0.1.4
#   [3e5b6fbb] + HostCPUFeatures v0.1.14
#   [7869d1d1] + IRTools v0.4.8
#   [615f187c] + IfElse v0.1.1
#   [22cec73e] + InitialValues v0.3.1
#   [3587e190] + InverseFunctions v0.1.8
#   [92d709cd] + IrrationalConstants v0.2.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.4.1
#   [0f8b85d8] + JSON3 v1.12.0
#   [929cbde3] + LLVM v4.16.0
#   [2ee39098] + LabelledArrays v1.14.0
#   [10f19ff3] + LayoutPointers v0.1.14
#   [d3d80556] + LineSearches v7.2.0
#   [2ab3a3ac] + LogExpFunctions v0.3.23
#   [bdcacae8] + LoopVectorization v0.12.152
#   [30fc2ffe] + LossFunctions v0.8.0
#   [d125e4d3] + ManualMemory v0.1.8
# ⌅ [e9d8d322] + Metatheory v1.3.5
#   [128add7d] + MicroCollections v0.1.3
#   [e1d29d7a] + Missings v1.1.0
#   [102ac46a] + MultivariatePolynomials v0.4.7
#   [d8a4904e] + MutableArithmetics v1.2.3
#   [d41bc354] + NLSolversBase v7.8.3
#   [77ba4419] + NaNMath v1.0.2
#   [6fe1bfb0] + OffsetArrays v1.12.9
#   [429524aa] + Optim v1.7.4
#   [bac558e1] + OrderedCollections v1.4.1
#   [d96e819e] + Parameters v0.12.3
#   [1d0040c9] + PolyesterWeave v0.2.1
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [d236fae5] + PreallocationTools v0.4.12
#   [49802e3a] + ProgressBars v1.4.1
#   [c1ae055f] + RealDot v0.1.0
#   [3cdcf5f2] + RecipesBase v1.3.3
#   [731186ca] + RecursiveArrayTools v2.38.0
#   [189a3867] + Reexport v1.2.2
#   [42d2dcc6] + Referenceables v0.1.2
#   [ae029012] + Requires v1.3.0
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.38
#   [efcf1570] + Setfield v1.1.1
#   [a2af1166] + SortingAlgorithms v1.1.0
#   [276daf66] + SpecialFunctions v2.2.0
#   [171d559e] + SplittablesBase v0.1.15
#   [aedffcd0] + Static v0.8.4
#   [0d7ed370] + StaticArrayInterface v1.3.0
#   [90137ffa] + StaticArrays v1.5.16
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [82ae8749] + StatsAPI v1.5.0
#   [2913bbd2] + StatsBase v0.33.21
#   [09ab397b] + StructArrays v0.6.14
#   [856f2bd8] + StructTypes v1.10.0
#   [2efcf032] + SymbolicIndexingInterface v0.2.2
#   [8254be44] + SymbolicRegression v0.15.3 `https://github.com/MilesCranmer/SymbolicRegression.jl#v0.15.3`
# ⌅ [d1185830] + SymbolicUtils v0.19.11
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.10.0
# ⌅ [8ea1fca8] + TermInterface v0.2.3
#   [8290d209] + ThreadingUtilities v0.5.1
#   [ac1d9e8a] + ThreadsX v0.1.11
#   [a759f4b9] + TimerOutputs v0.5.22
#   [28d57a85] + Transducers v0.4.75
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.61
#   [e88e6eb3] + Zygote v0.6.56
#   [700de1a5] + ZygoteRules v0.2.2
#   [dad2f222] + LLVMExtra_jll v0.0.16+2
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [4af54fe1] + LazyArtifacts
#   [76f85450] + LibGit2
#   [56ddb016] + Logging
#   [44cfe95a] + Pkg v1.8.0
#   [3fa0cd96] + REPL
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [a4e569a6] + Tar v1.10.1
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [3f19e933] + p7zip_jll v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# /usr/local/lib/python3.9/dist-packages/pysr/julia_helpers.py:105: UserWarning: It is recommended to restart Python after installing PySR's dependencies, so that the Julia environment is properly initialized.
#   warnings.warn(

# %%
import sympy
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('https://raw.githubusercontent.com/mhkarimid/Data/main/newdata.csv', 
               names=['Time (min)', 'Gold grade (g/ton)', 'Pyrite content (wt.%)',
               'Ore content (wt.%)', 'pH', 'ORP (mV)', 'D-Gal (wt.%)',
               'D-Suc (wt.%)', 'D-FrU (wt.%)', 'Ferric (g/lit)', 'Pyrite dissolution (%)'])

# %%
df
# Out:
#       Time (min)  Gold grade (g/ton)  Pyrite content (wt.%)  \
# 0      -0.500000                 0.5                    0.5
# 1      -0.456522                 0.5                    0.5
# 2      -0.413043                 0.5                    0.5
# 3      -0.369565                 0.5                    0.5
# 4      -0.326087                 0.5                    0.5
# ...          ...                 ...                    ...
# 3019    0.326087                -0.5                   -0.5
# 3020    0.369565                -0.5                   -0.5
# 3021    0.413043                -0.5                   -0.5
# 3022    0.456522                -0.5                   -0.5
# 3023    0.500000                -0.5                   -0.5
#
#       Ore content (wt.%)        pH  ORP (mV)  D-Gal (wt.%)  D-Suc (wt.%)  \
# 0              -0.444444 -0.191734 -0.460602     -0.155844     -0.155844
# 1              -0.444444 -0.201303 -0.443605     -0.155844     -0.155844
# 2              -0.444444 -0.244366 -0.432274     -0.155844     -0.155844
# 3              -0.444444 -0.273074 -0.304795     -0.155844     -0.155844
# 4              -0.444444 -0.225227 -0.214143     -0.155844     -0.155844
# ...                  ...       ...       ...           ...           ...
# 3019            0.555556  0.028362  0.159794     -0.155844     -0.155844
# 3020            0.555556  0.095347  0.145630     -0.155844     -0.155844
# 3021            0.555556  0.033146  0.080474     -0.155844     -0.155844
# 3022            0.555556  0.028362  0.159794     -0.155844     -0.155844
# 3023            0.555556 -0.029055  0.176792     -0.155844     -0.155844
#
#       D-FrU (wt.%)  Ferric (g/lit)  Pyrite dissolution (%)
# 0        -0.155844       -0.177262               -0.339150
# 1        -0.155844       -0.161934               -0.323117
# 2        -0.155844       -0.165186               -0.327591
# 3        -0.155844       -0.131744               -0.278188
# 4        -0.155844       -0.118739               -0.251342
# ...            ...             ...                     ...
# 3019      0.844156       -0.157754               -0.035272
# 3020      0.844156       -0.162399               -0.106488
# 3021      0.844156       -0.162399               -0.124385
# 3022      0.844156       -0.160541               -0.080201
# 3023      0.844156       -0.160077               -0.071998
#
# [3024 rows x 11 columns]

# %%
XX=df.drop(['Gold grade (g/ton)','Ferric (g/lit)','Pyrite dissolution (%)'], axis=1)

# %%
yy=df['Ferric (g/lit)']

# %%
X = XX.values.tolist()
y = yy.transpose().values.tolist()

# %%
default_pysr_params = dict(
    populations=10,
    model_selection="accuracy",
    loss="L1DistLoss()",
    maxsize=30,
    precision=16,
)

# %%
# Learn equations
model = PySRRegressor( 
    niterations=100,
    binary_operators=["+", "-", "*", "/", "^"],
    unary_operators=["inv(x) = 1/x", "P2(x)=x", "P3(x)=x", "P4(x)=x", "exp", "neg", "erf","sinh", "cosh"],
    extra_sympy_mappings={"inv": lambda x: 1/x, "P2": lambda x: x**0.3, "P3": lambda x: x**0.5, "P4": lambda x: x**0.7},
    
    **default_pysr_params
)

model.fit(X, y)
# Out:
# /usr/local/lib/python3.9/dist-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pysr/julia_helpers.py:217: UserWarning: Julia has already started. The new Julia options {'threads': 2} will be ignored.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.550e-02  3.914e-03  (((erf(x4) + x2) + x1) * 0.267)
# 9           7.062e-02  6.662e-02  ((x1 + (x4 + (x2 / 1.426))) * 0.2976)
# 11          6.995e-02  4.660e-03  ((x1 + (erf(x4) + (x2 / P3(1.426)))) * 0.2976)
# 12          6.635e-02  5.263e-02  sinh((x1 + (x4 + (x2 / (1.426 - x4)))) * 0.2976)
# 14          6.274e-02  2.786e-02  P4(((x1 + x4) + erf(x2 * (P2(0.543) + x4))) * 0.3108)
# 15          5.966e-02  5.057e-02  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + x2)) * 0.2976)
# 16          5.905e-02  1.031e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + x2)) * P3(0.2976))
# 17          5.786e-02  2.022e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + x2)) * P4(0.2976))
# 18          4.425e-02  2.683e-01  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  5.192e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.955e-02  8.335e-03  ((x1 + ((x4 + sinh(sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 22          3.851e-02  2.672e-02  sinh((x1 + ((x4 + erf(sinh(x2 + x4) / P2(inv(x1)))) + (x2 / (1.426 - x4)))) * 0.2976)
# 23          3.812e-02  1.031e-02  sinh((x1 + ((x4 + sinh(erf(sinh(x2 + x4) / inv(x1)))) + (x2 / (1.426 - sinh(x4))))) * 0.2976)
# 24          3.787e-02  6.368e-03  sinh((x1 + ((x4 + sinh(erf(sinh(x2 + sinh(x4)) / inv(x1)))) + (x2 / (1.426 - sinh(x4))))) * 0.2976)
# 25          3.757e-02  8.335e-03  sinh((x1 + ((x4 + erf(P4(sinh(P4(sinh(x2 + x4)))) / inv(x1))) + P2(x2 / (1.426 - x4)))) * 0.2976)
# 26          3.665e-02  2.472e-02  sinh(P3(P2(sinh((x1 + ((x4 + ((x2 + P4(x4 / 0.5083)) / inv(x1))) + (P3(x2) / (1.426 - x4)))) * 0.2976))))
# 27          3.644e-02  5.877e-03  P4(sinh((x1 + ((x4 + sinh(erf(sinh((x2 + erf(erf(x4))) / inv(sinh(x1)))))) + (x2 / (1.426 - erf(x4))))) * 0.2976))
# 28          3.436e-02  5.883e-02  sinh((sinh(x1) + (erf(erf(sinh(sinh(x4 + (P4((x2 + x4) + x4) / inv(x1)))))) + P4(x2 / (1.426 - x4)))) * 0.2976)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.980e+03
# Head worker occupation: 0.3%
# Progress: 110 / 1000 total iterations (11.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.434e-02  1.972e-02  ((x1 + (erf(x4) + x2)) * 0.2286)
# 9           7.025e-02  5.676e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 11          6.915e-02  7.874e-03  ((erf(x1 + P4(x4)) + (x2 * 0.543)) * 0.3108)
# 12          6.635e-02  4.137e-02  sinh((x1 + (x4 + (x2 / (1.426 - x4)))) * 0.2976)
# 14          6.274e-02  2.786e-02  P4(((x1 + x4) + erf(x2 * (P2(0.543) + x4))) * 0.3108)
# 15          5.927e-02  5.727e-02  ((x1 + ((x4 + (x2 / inv(x1))) + (x2 / 1.426))) * P2(0.2976))
# 16          5.786e-02  2.422e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + x2)) * 0.2976)
# 17          4.660e-02  2.167e-01  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  5.160e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  5.192e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.955e-02  8.335e-03  ((x1 + ((x4 + sinh(sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 22          3.851e-02  2.672e-02  sinh((x1 + ((x4 + erf(sinh(x2 + x4) / P2(inv(x1)))) + (x2 / (1.426 - x4)))) * 0.2976)
# 23          3.812e-02  1.031e-02  sinh((x1 + ((x4 + sinh(erf(sinh(x2 + x4) / inv(x1)))) + (x2 / (1.426 - sinh(x4))))) * 0.2976)
# 24          3.787e-02  6.368e-03  sinh((x1 + ((x4 + sinh(erf(sinh(x2 + sinh(x4)) / inv(x1)))) + (x2 / (1.426 - sinh(x4))))) * 0.2976)
# 25          3.757e-02  8.335e-03  sinh((x1 + ((x4 + erf(P4(sinh(P4(sinh(x2 + x4)))) / inv(x1))) + P2(x2 / (1.426 - x4)))) * 0.2976)
# 26          3.665e-02  2.472e-02  sinh(P3(P2(sinh((x1 + ((x4 + ((x2 + P4(x4 / 0.5083)) / inv(x1))) + (P3(x2) / (1.426 - x4)))) * 0.2976))))
# 27          3.555e-02  3.024e-02  ((x1 + (erf(erf(sinh(x4 + (P4((x2 + x4) + x4) / inv(x1))))) + P4(P4(P2(x2) / (1.426 - x4))))) * 0.2976)
# 28          3.436e-02  3.427e-02  sinh((sinh(x1) + (erf(erf(sinh(sinh(x4 + (P4((x2 + x4) + x4) / inv(x1)))))) + P4(x2 / (1.426 - x4)))) * 0.2976)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.990e+03
# Head worker occupation: 0.3%
# Progress: 116 / 1000 total iterations (11.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 11          6.641e-02  2.812e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.628e-02  1.955e-03  ((x1 + (x4 + (x2 / (1.648 - sinh(x1))))) * 0.27)
# 13          6.384e-02  3.731e-02  erf((x1 + (x4 + sinh(x2 / (1.648 - x1)))) * 0.27)
# 14          6.274e-02  1.724e-02  P4(((x1 + x4) + erf(x2 * (P2(0.543) + x4))) * 0.3108)
# 15          5.927e-02  5.727e-02  ((x1 + ((x4 + (x2 / inv(x1))) + (x2 / 1.426))) * P2(0.2976))
# 16          5.786e-02  2.422e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + x2)) * 0.2976)
# 17          4.660e-02  2.167e-01  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  5.160e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  5.192e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.751e-02  6.142e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / P2(inv(x1)))) + (x2 / (1.426 - x4)))) * 0.2976)
# 23          3.726e-02  3.184e-03  ((x1 + ((x4 + ((x2 + P4(x4 / erf(0.5083))) / inv(x1))) + (P3(x2) / (1.426 - x4)))) * 0.2976)
# 24          3.711e-02  3.914e-03  ((x1 + ((x4 + ((x2 + (x4 / erf(0.5083))) / inv(x1))) + (P3(x2) / P4(1.426 - erf(x4))))) * 0.2976)
# 25          3.680e-02  8.335e-03  ((sinh(x1) + ((x4 + ((x2 + P4(x4 / 0.5083)) / inv(x1))) + (P3(x2) / P4(1.426 - erf(x4))))) * 0.2976)
# 26          3.665e-02  3.914e-03  sinh(P3(P2(sinh((x1 + ((x4 + ((x2 + P4(x4 / 0.5083)) / inv(x1))) + (P3(x2) / (1.426 - x4)))) * 0.2976))))
# 27          3.555e-02  3.024e-02  ((x1 + (erf(erf(sinh(x4 + (P4((x2 + x4) + x4) / inv(x1))))) + P4(P4(P2(x2) / (1.426 - x4))))) * 0.2976)
# 28          3.436e-02  3.427e-02  sinh((sinh(x1) + (erf(erf(sinh(sinh(x4 + (P4((x2 + x4) + x4) / inv(x1)))))) + P4(x2 / (1.426 - x4)))) * 0.2976)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.050e+03
# Head worker occupation: 0.3%
# Progress: 122 / 1000 total iterations (12.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.250e-02  6.038e-02  (((x1 + P4(x4)) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.244e-02  9.770e-04  sinh(((x1 + P4(x4)) + (x2 * (0.543 + x4))) * 0.3108)
# 14          5.875e-02  6.090e-02  (((x1 + x4) + (x2 * P2(0.683 + P4(x1)))) * P2(0.3108))
# 16          5.786e-02  7.626e-03  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + x2)) * 0.2976)
# 17          4.660e-02  2.167e-01  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  5.160e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  5.192e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.751e-02  6.142e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / P2(inv(x1)))) + (x2 / (1.426 - x4)))) * 0.2976)
# 23          3.668e-02  1.111e-02  ((P3(x1) + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  8.029e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.351e-02  9.814e-03  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 26          3.320e-02  9.321e-03  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (sinh(x2) / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 28          3.314e-02  9.775e-04  erf((x1 + (P3(x4 + (P3((x2 + P2(x4)) + x4) / inv(x1))) + (sinh(x2) / sinh(1.426 - (x4 * 1.78))))) * 0.2976)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.040e+03
# Head worker occupation: 0.3%
# Progress: 127 / 1000 total iterations (12.700%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.250e-02  6.038e-02  (((x1 + P4(x4)) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.244e-02  9.770e-04  sinh(((x1 + P4(x4)) + (x2 * (0.543 + x4))) * 0.3108)
# 14          5.875e-02  6.090e-02  (((x1 + x4) + (x2 * P2(0.683 + P4(x1)))) * P2(0.3108))
# 16          4.691e-02  1.126e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.660e-02  6.368e-03  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  5.160e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.254e-02  3.934e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.454e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.735e-02  6.558e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / (1.426 - erf(x4))))) * 0.2976)
# 23          3.668e-02  9.116e-03  ((P3(x1) + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  8.029e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.351e-02  9.814e-03  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 26          3.320e-02  9.321e-03  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (sinh(x2) / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 28          3.314e-02  9.775e-04  erf((x1 + (P3(x4 + (P3((x2 + P2(x4)) + x4) / inv(x1))) + (sinh(x2) / sinh(1.426 - (x4 * 1.78))))) * 0.2976)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.040e+03
# Head worker occupation: 0.3%
# Progress: 133 / 1000 total iterations (13.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.250e-02  6.038e-02  (((x1 + P4(x4)) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.244e-02  9.770e-04  sinh(((x1 + P4(x4)) + (x2 * (0.543 + x4))) * 0.3108)
# 14          5.875e-02  6.090e-02  (((x1 + x4) + (x2 * P2(0.683 + P4(x1)))) * P2(0.3108))
# 16          4.691e-02  1.126e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.660e-02  6.368e-03  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  5.160e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.254e-02  3.934e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.454e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.735e-02  6.558e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / (1.426 - erf(x4))))) * 0.2976)
# 23          3.668e-02  9.116e-03  ((P3(x1) + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  8.029e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.351e-02  9.814e-03  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 26          3.320e-02  9.321e-03  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (sinh(x2) / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 27          3.317e-02  9.770e-04  erf((x1 + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (erf(sinh(x2)) / (sinh(1.426 - x4) + x3)))) * 0.2976)
# 28          3.296e-02  6.368e-03  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (erf(sinh(x2)) / (sinh(1.426 - x4) + x3)))) * 0.2976)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.120e+03
# Head worker occupation: 0.3%
# Progress: 139 / 1000 total iterations (13.900%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.061e-02  2.973e-02  sinh((erf(x1 + x4) + (x2 * (0.5654 + x4))) * 0.3108)
# 14          5.859e-02  3.377e-02  sinh(((x1 + x4) + (x2 * (0.683 + P3(x1)))) * P2(0.3108))
# 15          5.841e-02  2.934e-03  P3(((sinh(x1) + x4) + (sinh(x2) * P3(0.683 + x1))) * 0.3108)
# 16          4.691e-02  2.191e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.660e-02  6.368e-03  ((x1 + ((x4 + ((sinh(x2) + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  5.160e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.254e-02  3.934e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.454e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.735e-02  6.558e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / (1.426 - erf(x4))))) * 0.2976)
# 23          3.668e-02  9.116e-03  ((P3(x1) + ((x4 + (P3((x2 + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  8.029e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.088e-02  1.628e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - sinh(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.020e+03
# Head worker occupation: 0.3%
# Progress: 144 / 1000 total iterations (14.400%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.061e-02  2.973e-02  sinh((erf(x1 + x4) + (x2 * (0.5654 + x4))) * 0.3108)
# 14          5.859e-02  3.377e-02  sinh(((x1 + x4) + (x2 * (0.683 + P3(x1)))) * P2(0.3108))
# 15          5.841e-02  2.934e-03  P3(((sinh(x1) + x4) + (sinh(x2) * P3(0.683 + x1))) * 0.3108)
# 16          4.691e-02  2.191e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.645e-02  9.814e-03  ((x1 + (sinh(x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  4.852e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.254e-02  3.934e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.454e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.735e-02  6.558e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / (1.426 - erf(x4))))) * 0.2976)
# 23          3.568e-02  2.298e-02  ((x1 + ((P4(x4) + (((x2 + x4) + x4) / inv(x1))) + (erf(x2) / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  5.263e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.088e-02  1.628e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - sinh(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.060e+03
# Head worker occupation: 0.3%
# Progress: 149 / 1000 total iterations (14.900%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.061e-02  2.973e-02  sinh((erf(x1 + x4) + (x2 * (0.5654 + x4))) * 0.3108)
# 14          5.859e-02  3.377e-02  sinh(((x1 + x4) + (x2 * (0.683 + P3(x1)))) * P2(0.3108))
# 15          5.841e-02  2.934e-03  P3(((sinh(x1) + x4) + (sinh(x2) * P3(0.683 + x1))) * 0.3108)
# 16          4.691e-02  2.191e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.645e-02  9.814e-03  ((x1 + (sinh(x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  4.852e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.242e-02  4.239e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.536)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.142e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.735e-02  6.558e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / (1.426 - erf(x4))))) * 0.2976)
# 23          3.568e-02  2.298e-02  ((x1 + ((P4(x4) + (((x2 + x4) + x4) / inv(x1))) + (erf(x2) / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  5.263e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.088e-02  1.628e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - sinh(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.020e+03
# Head worker occupation: 0.3%
# Progress: 156 / 1000 total iterations (15.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.061e-02  2.973e-02  sinh((erf(x1 + x4) + (x2 * (0.5654 + x4))) * 0.3108)
# 14          5.859e-02  3.377e-02  sinh(((x1 + x4) + (x2 * (0.683 + P3(x1)))) * P2(0.3108))
# 15          5.841e-02  2.934e-03  P3(((sinh(x1) + x4) + (sinh(x2) * P3(0.683 + x1))) * 0.3108)
# 16          4.691e-02  2.191e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.645e-02  9.814e-03  ((x1 + (sinh(x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  4.852e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.242e-02  4.239e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.536)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.142e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.735e-02  6.558e-02  ((x1 + ((x4 + ((x2 + (x4 / 0.5083)) / inv(x1))) + (x2 / (1.426 - erf(x4))))) * 0.2976)
# 23          3.568e-02  2.298e-02  ((x1 + ((P4(x4) + (((x2 + x4) + x4) / inv(x1))) + (erf(x2) / sinh(1.426 - x4)))) * 0.2976)
# 24          3.384e-02  5.263e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.088e-02  1.628e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - sinh(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.010e+03
# Head worker occupation: 0.3%
# Progress: 163 / 1000 total iterations (16.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.061e-02  2.973e-02  sinh((erf(x1 + x4) + (x2 * (0.5654 + x4))) * 0.3108)
# 14          5.859e-02  3.377e-02  sinh(((x1 + x4) + (x2 * (0.683 + P3(x1)))) * P2(0.3108))
# 15          5.841e-02  2.934e-03  P3(((sinh(x1) + x4) + (sinh(x2) * P3(0.683 + x1))) * 0.3108)
# 16          4.691e-02  2.191e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.645e-02  9.814e-03  ((x1 + (sinh(x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.425e-02  4.852e-02  ((x1 + ((x4 + (sinh(sinh(x2 + x4)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 19          4.242e-02  4.239e-02  ((erf(x1) + ((x4 + ((x2 + (x4 / 0.536)) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 20          3.989e-02  6.142e-02  ((x1 + ((x4 + (sinh(x2 + sinh(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 21          3.687e-02  7.870e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.677e-02  2.444e-03  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + sinh(x2 / (1.607 - sinh(x4))))) * 0.2976)
# 23          3.555e-02  3.377e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / ((1.607 - sinh(x4)) - x1)))) * 0.2976)
# 24          3.384e-02  4.903e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.870e+03
# Head worker occupation: 0.3%
# Progress: 171 / 1000 total iterations (17.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          6.061e-02  2.973e-02  sinh((erf(x1 + x4) + (x2 * (0.5654 + x4))) * 0.3108)
# 14          5.859e-02  3.377e-02  sinh(((x1 + x4) + (x2 * (0.683 + P3(x1)))) * P2(0.3108))
# 15          5.841e-02  2.934e-03  P3(((sinh(x1) + x4) + (sinh(x2) * P3(0.683 + x1))) * 0.3108)
# 16          4.691e-02  2.191e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.645e-02  9.814e-03  ((x1 + (sinh(x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.184e-02  1.044e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 19          4.010e-02  4.239e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 20          3.961e-02  1.228e-02  ((x1 + ((x4 + erf((x2 + erf(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 21          3.687e-02  7.186e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.677e-02  2.444e-03  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + sinh(x2 / (1.607 - sinh(x4))))) * 0.2976)
# 23          3.555e-02  3.377e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / ((1.607 - sinh(x4)) - x1)))) * 0.2976)
# 24          3.384e-02  4.903e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.860e+03
# Head worker occupation: 0.3%
# Progress: 177 / 1000 total iterations (17.700%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          5.835e-02  6.767e-02  (((sinh(x1) + x4) + (x2 * (0.683 + x1))) * P3(0.3108))
# 15          5.399e-02  3.882e-02  (((sinh(x1) + x4) + (x2 * ((0.683 + x4) + P2(x1)))) * 0.3108)
# 16          4.691e-02  1.408e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.645e-02  9.814e-03  ((x1 + (sinh(x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 18          4.184e-02  1.044e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 19          4.010e-02  4.239e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 20          3.961e-02  1.228e-02  ((x1 + ((x4 + erf((x2 + erf(x4)) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 21          3.687e-02  7.186e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.677e-02  2.444e-03  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + sinh(x2 / (1.607 - sinh(x4))))) * 0.2976)
# 23          3.555e-02  3.377e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / ((1.607 - sinh(x4)) - x1)))) * 0.2976)
# 24          3.384e-02  4.903e-02  erf((x1 + ((x4 + (P3((erf(x2) + x4) + x4) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * 0.2976)
# 25          3.329e-02  1.624e-02  (P3(x1 + ((P2(x4) + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 26          3.262e-02  2.022e-02  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.950e+03
# Head worker occupation: 0.3%
# Progress: 186 / 1000 total iterations (18.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          6.244e-02  6.142e-02  sinh(((x1 + x4) + (x2 * (0.543 + x4))) * 0.3108)
# 13          5.835e-02  6.767e-02  (((sinh(x1) + x4) + (x2 * (0.683 + x1))) * P3(0.3108))
# 15          5.399e-02  3.882e-02  (((sinh(x1) + x4) + (x2 * ((0.683 + x4) + P2(x1)))) * 0.3108)
# 16          4.691e-02  1.408e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.565e-02  2.722e-02  ((x1 + ((x4 + ((x2 + x4) / inv(erf(x1)))) + (x2 / 1.426))) * 0.3262)
# 18          4.184e-02  8.719e-02  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 19          4.010e-02  4.239e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 20          3.842e-02  4.290e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 21          3.687e-02  4.137e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.619e-02  1.823e-02  ((x1 + (P3(x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426) - x4)))) * 0.3262)
# 23          3.329e-02  8.347e-02  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 24          3.323e-02  1.955e-03  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 25          3.278e-02  1.377e-02  sinh((x1 + ((x4 + ((erf(x2) + (x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 26          3.262e-02  4.895e-03  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.970e+03
# Head worker occupation: 0.3%
# Progress: 191 / 1000 total iterations (19.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.641e-02  4.035e-02  ((x1 + (x4 + (x2 / (1.648 - x1)))) * 0.27)
# 12          5.872e-02  1.230e-01  (((x1 + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 13          5.829e-02  7.351e-03  (((sinh(x1) + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 15          5.399e-02  3.830e-02  (((sinh(x1) + x4) + (x2 * ((0.683 + x4) + P2(x1)))) * 0.3108)
# 16          4.691e-02  1.408e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.565e-02  2.722e-02  ((x1 + ((x4 + ((x2 + x4) / inv(erf(x1)))) + (x2 / 1.426))) * 0.3262)
# 18          4.178e-02  8.879e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / 1.607))) * 0.2976)
# 19          4.010e-02  4.086e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 20          3.842e-02  4.290e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.3262)
# 21          3.687e-02  4.137e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.619e-02  1.823e-02  ((x1 + (P3(x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426) - x4)))) * 0.3262)
# 23          3.329e-02  8.347e-02  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 24          3.323e-02  1.955e-03  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 25          3.278e-02  1.377e-02  sinh((x1 + ((x4 + ((erf(x2) + (x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 26          3.262e-02  4.895e-03  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.050e+03
# Head worker occupation: 0.3%
# Progress: 199 / 1000 total iterations (19.900%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          6.604e-02  4.596e-02  ((x1 + (x4 + (x2 / (1.607 - x4)))) * 0.2976)
# 12          5.872e-02  1.175e-01  (((x1 + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 13          5.829e-02  7.351e-03  (((sinh(x1) + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 15          5.399e-02  3.830e-02  (((sinh(x1) + x4) + (x2 * ((0.683 + x4) + P2(x1)))) * 0.3108)
# 16          4.691e-02  1.408e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.565e-02  2.722e-02  ((x1 + ((x4 + ((x2 + x4) / inv(erf(x1)))) + (x2 / 1.426))) * 0.3262)
# 18          4.178e-02  8.879e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / 1.607))) * 0.2976)
# 19          4.010e-02  4.086e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 20          3.693e-02  8.241e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - x4)))) * 0.2976)
# 21          3.687e-02  1.466e-03  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.619e-02  1.823e-02  ((x1 + (P3(x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426) - x4)))) * 0.3262)
# 23          3.329e-02  8.347e-02  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 24          3.323e-02  1.955e-03  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 25          3.278e-02  1.377e-02  sinh((x1 + ((x4 + ((erf(x2) + (x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 26          3.262e-02  4.895e-03  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.020e+03
# Head worker occupation: 0.3%
# Progress: 206 / 1000 total iterations (20.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          5.875e-02  1.630e-01  (((x1 + x4) + (x2 * (x1 + 0.683))) * 0.3108)
# 12          5.872e-02  4.884e-04  (((x1 + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 13          5.829e-02  7.351e-03  (((sinh(x1) + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 14          5.823e-02  9.770e-04  sinh(P3(((sinh(x1) + x4) + (x2 * (x1 + 0.683))) * 0.3108))
# 15          5.399e-02  7.554e-02  (((sinh(x1) + x4) + (x2 * ((0.683 + x4) + P2(x1)))) * 0.3108)
# 16          4.691e-02  1.408e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.565e-02  2.722e-02  ((x1 + ((x4 + ((x2 + x4) / inv(erf(x1)))) + (x2 / 1.426))) * 0.3262)
# 18          4.132e-02  9.952e-02  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 19          4.010e-02  3.024e-02  ((x1 + ((x4 + (sinh(x2 + x4) / inv(x1))) + (x2 / (1.426 - x4)))) * 0.2976)
# 20          3.693e-02  8.241e-02  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - x4)))) * 0.2976)
# 21          3.687e-02  1.466e-03  ((x1 + ((x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (1.607 - sinh(x4))))) * 0.2976)
# 22          3.619e-02  1.823e-02  ((x1 + (P3(x4 + (((x2 + x4) + x4) / inv(x1))) + (x2 / (sinh(1.426) - x4)))) * 0.3262)
# 23          3.329e-02  8.347e-02  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * erf(0.2976))
# 24          3.323e-02  1.955e-03  ((x1 + ((x4 + ((x2 + P3(x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 25          3.278e-02  1.377e-02  sinh((x1 + ((x4 + ((erf(x2) + (x4 / 0.5083)) / inv(x1))) + (x2 / sinh(1.426 - x4)))) * sinh(erf(0.2976)))
# 26          3.262e-02  4.895e-03  ((x1 + ((erf(x4) + ((x2 + (P2(x4) / 0.5083)) / P3(inv(x1)))) + (x2 / (sinh(1.426 - x4) - x4)))) * 0.2976)
# 27          3.090e-02  5.418e-02  ((x1 + ((erf(x4) + ((x2 + (P4(x4) / 0.5083)) / inv(x1))) + P3(x2 / (sinh(1.426 - x4) - x4)))) * erf(0.2976))
# 30          3.082e-02  8.148e-04  ((x1 + ((erf(x4) + ((P2(x2) + (P4(x4) / 0.5083)) / inv(P2(x1)))) + P3(x2 / (sinh(1.426 - x4) - erf(x4))))) * erf(0.2976))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.050e+03
# Head worker occupation: 0.3%
# Progress: 211 / 1000 total iterations (21.100%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          5.875e-02  1.630e-01  (((x1 + x4) + (x2 * (x1 + 0.683))) * 0.3108)
# 12          5.872e-02  4.884e-04  (((x1 + x4) + (x2 * (sinh(x1) + 0.683))) * 0.3108)
# 13          5.710e-02  2.772e-02  P4((erf(x1 + x4) + (x2 * (x1 + 0.676))) * 0.3108)
# 14          5.704e-02  9.770e-04  ((erf(x1 + x4) + (x2 * (P4(x1) + 0.676))) * sinh(0.3108))
# 15          5.399e-02  5.521e-02  (((sinh(x1) + x4) + (x2 * ((0.683 + x4) + P2(x1)))) * 0.3108)
# 16          4.691e-02  1.408e-01  ((x1 + ((x4 + ((x2 + x4) / inv(x1))) + (x2 / 1.426))) * 0.2976)
# 17          4.565e-02  2.722e-02  ((x1 + ((x4 + ((x2 + x4) / inv(erf(x1)))) + (x2 / 1.426))) * 0.3262)
# ...
# 19          3.134e-02  5.315e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 20          3.113e-02  6.859e-03  ((((sinh(x1) * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 21          2.742e-02  1.269e-01  ((((x1 * ((x4 / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 22          2.687e-02  2.022e-02  ((((x1 * ((erf(x4) / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 23          2.570e-02  4.494e-02  ((((sinh(x1) * ((x4 / erf(0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 24          2.480e-02  3.579e-02  erf(((sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.8735)) + x4) + (x2 * ((x1 + x4) + 0.5234))) * 0.3203)
# 25          2.423e-02  2.322e-02  erf(((sinh(sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 26          2.391e-02  1.327e-02  erf(((sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 27          2.390e-02  4.884e-04  erf(((sinh(sinh(sinh(x1)) * ((x4 / P3(erf(0.8975 - x2))) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.538))) * 0.3203)
# 29          2.386e-02  7.330e-04  P3(erf(((P2(sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((sinh(x1) + x4) + 0.541))) * 0.3203))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.400e+03
# Head worker occupation: 0.4%
# Progress: 967 / 1000 total iterations (96.700%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          5.850e-02  1.670e-01  (((x1 + x4) + (x2 * (x1 + 0.642))) * 0.3284)
# 12          5.692e-02  2.772e-02  ((erf(x1 + x4) + (x2 * (x1 + 0.6484))) * 0.324)
# 13          5.310e-02  6.924e-02  (((x1 + x4) + (x2 * ((x1 + x4) + 0.5454))) * 0.3362)
# 14          5.154e-02  2.973e-02  ((erf(x1 + x4) + (x2 * (x1 + (0.6074 + x4)))) * 0.324)
# 15          4.578e-02  1.186e-01  ((((x1 * (x4 + 0.8936)) + x4) + (x2 * (x1 + 0.5806))) * 0.3362)
# 16          4.294e-02  6.402e-02  ((((x1 * sinh(x4 + 0.833)) + x4) + (x2 * (x1 + 0.6074))) * 0.324)
# 17          3.510e-02  2.016e-01  ((((x1 * (x4 + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.536))) * 0.3672)
# 18          3.305e-02  5.986e-02  ((((x1 * sinh(x4 + 0.804)) + x4) + (x2 * ((x4 + x1) + 0.571))) * 0.3362)
# 19          3.134e-02  5.315e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 20          3.113e-02  6.859e-03  ((((sinh(x1) * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 21          2.742e-02  1.269e-01  ((((x1 * ((x4 / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 22          2.687e-02  2.022e-02  ((((x1 * ((erf(x4) / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 23          2.570e-02  4.494e-02  ((((sinh(x1) * ((x4 / erf(0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 24          2.480e-02  3.579e-02  erf(((sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.8735)) + x4) + (x2 * ((x1 + x4) + 0.5234))) * 0.3203)
# 25          2.423e-02  2.322e-02  erf(((sinh(sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 26          2.391e-02  1.327e-02  erf(((sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 27          2.390e-02  4.884e-04  erf(((sinh(sinh(sinh(x1)) * ((x4 / P3(erf(0.8975 - x2))) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.538))) * 0.3203)
# 29          2.386e-02  7.330e-04  P3(erf(((P2(sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((sinh(x1) + x4) + 0.541))) * 0.3203))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.470e+03
# Head worker occupation: 0.4%
# Progress: 977 / 1000 total iterations (97.700%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          5.850e-02  1.670e-01  (((x1 + x4) + (x2 * (x1 + 0.642))) * 0.3284)
# 12          5.692e-02  2.772e-02  ((erf(x1 + x4) + (x2 * (x1 + 0.6484))) * 0.324)
# 13          5.310e-02  6.924e-02  (((x1 + x4) + (x2 * ((x1 + x4) + 0.5454))) * 0.3362)
# 14          5.154e-02  2.973e-02  ((erf(x1 + x4) + (x2 * (x1 + (0.6074 + x4)))) * 0.324)
# 15          4.578e-02  1.186e-01  ((((x1 * (x4 + 0.8936)) + x4) + (x2 * (x1 + 0.5806))) * 0.3362)
# 16          4.294e-02  6.402e-02  ((((x1 * sinh(x4 + 0.833)) + x4) + (x2 * (x1 + 0.6074))) * 0.324)
# 17          3.510e-02  2.016e-01  ((((x1 * (x4 + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.536))) * 0.3672)
# 18          3.305e-02  5.986e-02  ((((x1 * sinh(x4 + 0.804)) + x4) + (x2 * ((x4 + x1) + 0.571))) * 0.3362)
# 19          3.134e-02  5.315e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 20          3.075e-02  1.923e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * (erf(x1 + x4) + 0.5303))) * 0.362)
# 21          2.742e-02  1.147e-01  ((((x1 * ((x4 / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 22          2.687e-02  2.022e-02  ((((x1 * ((erf(x4) / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 23          2.553e-02  5.109e-02  ((((sinh(x1) * ((x4 / erf(0.8555 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 24          2.480e-02  2.923e-02  erf(((sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.8735)) + x4) + (x2 * ((x1 + x4) + 0.5234))) * 0.3203)
# 25          2.423e-02  2.322e-02  erf(((sinh(sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 26          2.391e-02  1.327e-02  erf(((sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 27          2.390e-02  4.884e-04  erf(((sinh(sinh(sinh(x1)) * ((x4 / P3(erf(0.8975 - x2))) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.538))) * 0.3203)
# 29          2.386e-02  7.330e-04  P3(erf(((P2(sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((sinh(x1) + x4) + 0.541))) * 0.3203))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.500e+03
# Head worker occupation: 0.4%
# Progress: 983 / 1000 total iterations (98.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          5.850e-02  1.670e-01  (((x1 + x4) + (x2 * (x1 + 0.642))) * 0.3284)
# 12          5.692e-02  2.772e-02  ((erf(x1 + x4) + (x2 * (x1 + 0.6484))) * 0.324)
# 13          5.310e-02  6.924e-02  (((x1 + x4) + (x2 * ((x1 + x4) + 0.5454))) * 0.3362)
# 14          5.154e-02  2.973e-02  ((erf(x1 + x4) + (x2 * (x1 + (0.6074 + x4)))) * 0.324)
# 15          4.578e-02  1.186e-01  ((((x1 * (x4 + 0.8936)) + x4) + (x2 * (x1 + 0.5806))) * 0.3362)
# 16          4.294e-02  6.402e-02  ((((x1 * sinh(x4 + 0.833)) + x4) + (x2 * (x1 + 0.6074))) * 0.324)
# 17          3.510e-02  2.016e-01  ((((x1 * (x4 + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.536))) * 0.3672)
# 18          3.305e-02  5.986e-02  ((((x1 * sinh(x4 + 0.804)) + x4) + (x2 * ((x4 + x1) + 0.571))) * 0.3362)
# 19          3.134e-02  5.315e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 20          3.075e-02  1.923e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * (erf(x1 + x4) + 0.5303))) * 0.362)
# 21          2.742e-02  1.147e-01  ((((x1 * ((x4 / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 22          2.687e-02  2.022e-02  ((((x1 * ((erf(x4) / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 23          2.553e-02  5.109e-02  ((((sinh(x1) * ((x4 / erf(0.8555 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 24          2.480e-02  2.923e-02  erf(((sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.8735)) + x4) + (x2 * ((x1 + x4) + 0.5234))) * 0.3203)
# 25          2.423e-02  2.322e-02  erf(((sinh(sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 26          2.391e-02  1.327e-02  erf(((sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 27          2.390e-02  4.884e-04  erf(((sinh(sinh(sinh(x1)) * ((x4 / P3(erf(0.8975 - x2))) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.538))) * 0.3203)
# 29          2.386e-02  7.330e-04  P3(erf(((P2(sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((sinh(x1) + x4) + 0.541))) * 0.3203))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.570e+03
# Head worker occupation: 0.4%
# Progress: 993 / 1000 total iterations (99.300%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.398e-01  4.858e-02  -0.0566
# 3           1.057e-01  1.396e-01  (x1 * 0.3386)
# 4           1.057e-01  4.884e-04  (sinh(x1) * 0.3262)
# 5           9.155e-02  1.431e-01  ((x1 + x4) * 0.2712)
# 6           8.893e-02  2.923e-02  (erf(x4 + x1) * 0.267)
# 7           7.581e-02  1.595e-01  (((x4 + x2) + x1) * 0.2375)
# 8           7.428e-02  2.022e-02  (((erf(x4) + x2) + x1) * 0.2375)
# 9           7.025e-02  5.572e-02  ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 10          6.915e-02  1.575e-02  ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 11          5.850e-02  1.670e-01  (((x1 + x4) + (x2 * (x1 + 0.642))) * 0.3284)
# 12          5.692e-02  2.772e-02  ((erf(x1 + x4) + (x2 * (x1 + 0.6484))) * 0.324)
# 13          5.310e-02  6.924e-02  (((x1 + x4) + (x2 * ((x1 + x4) + 0.5454))) * 0.3362)
# 14          5.154e-02  2.973e-02  ((erf(x1 + x4) + (x2 * (x1 + (0.6074 + x4)))) * 0.324)
# 15          4.578e-02  1.186e-01  ((((x1 * (x4 + 0.8936)) + x4) + (x2 * (x1 + 0.5806))) * 0.3362)
# 16          4.294e-02  6.402e-02  ((((x1 * sinh(x4 + 0.833)) + x4) + (x2 * (x1 + 0.6074))) * 0.324)
# 17          3.510e-02  2.016e-01  ((((x1 * (x4 + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.536))) * 0.3672)
# 18          3.305e-02  5.986e-02  ((((x1 * sinh(x4 + 0.804)) + x4) + (x2 * ((x4 + x1) + 0.571))) * 0.3362)
# 19          3.134e-02  5.315e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * ((x1 + x4) + 0.5303))) * 0.362)
# 20          3.075e-02  1.923e-02  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 * (erf(x1 + x4) + 0.5303))) * 0.362)
# 21          2.742e-02  1.147e-01  ((((x1 * ((x4 / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 22          2.687e-02  2.022e-02  ((((x1 * ((erf(x4) / (0.9033 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 23          2.553e-02  5.109e-02  ((((sinh(x1) * ((x4 / erf(0.8555 - x2)) + 0.8623)) + x4) + (x2 * ((x1 + x4) + 0.513))) * 0.3672)
# 24          2.480e-02  2.923e-02  erf(((sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.8735)) + x4) + (x2 * ((x1 + x4) + 0.5234))) * 0.3203)
# 25          2.423e-02  2.322e-02  erf(((sinh(sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 26          2.391e-02  1.327e-02  erf(((sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.541))) * 0.3203)
# 27          2.390e-02  4.884e-04  erf(((sinh(sinh(sinh(x1)) * ((x4 / P3(erf(0.8975 - x2))) + 0.819)) + x4) + (x2 * ((x1 + x4) + 0.538))) * 0.3203)
# 29          2.386e-02  7.330e-04  P3(erf(((P2(sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 - x2)) + 0.819))) + x4) + (x2 * ((sinh(x1) + x4) + 0.541))) * 0.3203))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                            -0.0566
# 	1         0.139804                                      (x1 * 0.3386)
# 	2         0.000473                                (sinh(x1) * 0.3262)
# 	3         0.143246                               ((x1 + x4) * 0.2712)
# 	4         0.029373                             (erf(x4 + x1) * 0.267)
# 	5         0.159414                        (((x4 + x2) + x1) * 0.2375)
# 	6         0.019987                   (((erf(x4) + x2) + x1) * 0.2375)
# 	7         0.056051              ((x1 + (x4 + (x2 / 1.647))) * 0.2976)
# 	8         0.015782           ((erf(x1 + x4) + (x2 * 0.543)) * 0.3108)
# 	9         0.167251       (((x1 + x4) + (x2 * (x1 + 0.642))) * 0.3284)
# 	10        0.027380    ((erf(x1 + x4) + (x2 * (x1 + 0.6484))) * 0.324)
# 	11        0.069470  (((x1 + x4) + (x2 * ((x1 + x4) + 0.5454))) * 0...
# 	12        0.029819  ((erf(x1 + x4) + (x2 * (x1 + (0.6074 + x4)))) ...
# 	13        0.118511  ((((x1 * (x4 + 0.8936)) + x4) + (x2 * (x1 + 0....
# 	14        0.064044  ((((x1 * sinh(x4 + 0.833)) + x4) + (x2 * (x1 +...
# 	15        0.201603  ((((x1 * (x4 + 0.8623)) + x4) + (x2 * ((x1 + x...
# 	16        0.060180  ((((x1 * sinh(x4 + 0.804)) + x4) + (x2 * ((x4 ...
# 	17        0.053126  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 ...
# 	18        0.019005  ((((x1 * ((x4 * 1.568) + 0.8555)) + x4) + (x2 ...
# 	19        0.114617  ((((x1 * ((x4 / (0.9033 - x2)) + 0.8623)) + x4...
# 	20        0.020262  ((((x1 * ((erf(x4) / (0.9033 - x2)) + 0.8623))...
# 	21        0.051156  ((((sinh(x1) * ((x4 / erf(0.8555 - x2)) + 0.86...
# 	22        0.029011  erf(((sinh(x1 * ((x4 / erf(0.8975 - x2)) + 0.8...
# 	23        0.023252  erf(((sinh(sinh(x1 * ((x4 / erf(0.8975 - x2)) ...
# 	24        0.013295  erf(((sinh(sinh(sinh(x1)) * ((x4 / erf(0.8975 ...
# 	25        0.000418  erf(((sinh(sinh(sinh(x1)) * ((x4 / P3(erf(0.89...
# 	26  >>>>  0.000838  P3(erf(((P2(sinh(sinh(sinh(x1)) * ((x4 / erf(0...
#
# 	       loss  complexity
# 	0   0.13980           1
# 	1   0.10570           3
# 	2   0.10565           4
# 	3   0.09155           5
# 	4   0.08890           6
# 	5   0.07580           7
# 	6   0.07430           8
# 	7   0.07025           9
# 	8   0.06915          10
# 	9   0.05850          11
# 	10  0.05692          12
# 	11  0.05310          13
# 	12  0.05154          14
# 	13  0.04578          15
# 	14  0.04294          16
# 	15  0.03510          17
# 	16  0.03305          18
# 	17  0.03134          19
# 	18  0.03075          20
# 	19  0.02742          21
# 	20  0.02687          22
# 	21  0.02553          23
# 	22  0.02480          24
# 	23  0.02423          25
# 	24  0.02391          26
# 	25  0.02390          27
# 	26  0.02386          29
# ]

# %%
model.sympy()
# Out:
# erf(0.3203*x2*(x4 + sinh(x1) + 0.541) + 0.3203*x4 + 0.3203*sinh((-x4/erf(x2 - 0.8975) + 0.819)*sinh(sinh(x1)))**0.3)**0.5

# %%
y2=model.predict(X)
# Out:
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in power
#   return (sqrt(erf(0.3203*x2*(x4 + sinh(x1) + 0.541) + 0.3203*x4 + 0.3203*sinh((-x4/erf(x2 - 0.8975) + 0.819)*sinh(sinh(x1)))**0.3)))
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in sqrt
#   return (sqrt(erf(0.3203*x2*(x4 + sinh(x1) + 0.541) + 0.3203*x4 + 0.3203*sinh((-x4/erf(x2 - 0.8975) + 0.819)*sinh(sinh(x1)))**0.3)))

# %%
d=sns.scatterplot(x=y, y=y2)
d.set(xlabel='Ferric concentration-exp', ylabel='Ferric concentration-model')
# Out:
# [Text(0.5, 0, 'Ferric concentration-exp'),
#  Text(0, 0.5, 'Ferric concentration-model')]
